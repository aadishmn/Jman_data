# %%
# !pip install --user snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python in c:\users\aadishnagarajan\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (42.0.2)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (24.0.0)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: pytz in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (2023.3.post1)
# Requirement already satisfied: requests<3.0.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (2.31.0)
# Requirement already satisfied: packaging in c:\users\aadishnagarajan\appdata\roaming\python\python311\site-packages (from snowflake-connector-python) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (2024.2.2)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (4.9.0)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<4.0.0,>=2.6.0 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (3.10.0)
# Requirement already satisfied: tomlkit in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from snowflake-connector-python) (0.11.1)
# Requirement already satisfied: pycparser in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aadishnagarajan\anaconda3\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (1.26.18)

# %%
import snowflake.connector
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Establish connection
conn = snowflake.connector.connect(
          user='aadishmn',
            password='Qwert@123',
            account='tz70231.central-india.azure',
            warehouse='COMPUTE_WH',
            database='JMAN',
            schema='JMAN_SCHEMA',
            role='ACCOUNTADMIN'
)

cur = conn.cursor()

cur.execute(f'SELECT * FROM JMAN.JMAN_SCHEMA_MART.FINAL_TABLE')

rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# %%
dataset = pd.DataFrame(rows, columns=[x[0] for x in cur.description])

# %%
dataset.to_csv('src_data.csv', index=False)
df=dataset.copy()

# %%
df
# Out:
#       FIRST_NAME  LAST_NAME                 EMAIL  GENDER DOB_DD_MM_YYYY  \
# 0           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 1           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 2           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 3           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 4           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# ...          ...        ...                   ...     ...            ...
# 59449        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59450        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59451        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59452        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59453        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
#
#       USER_TYPE    ROLE  AGE                       CLIENT_NAME  \
# 0          User  intern   40  VonRueden, Bartell and Halvorson
# 1          User  intern   30                     Crist-Wiegand
# 2          User  intern   30                     Crist-Wiegand
# 3          User  intern   40  VonRueden, Bartell and Halvorson
# 4          User  intern   30  VonRueden, Bartell and Halvorson
# ...         ...     ...  ...                               ...
# 59449      User  intern   25                       Strosin Inc
# 59450      User  intern   25                       Strosin Inc
# 59451      User  intern   29                    Leannon-Grimes
# 59452      User  intern   29                    Leannon-Grimes
# 59453      User  intern   29                       Strosin Inc
#
#               PROJECT_NAME  ... HOURS_OVER_OR_UNDER FEEDBACK_START_PERIOD  \
# 0      Software_Developper  ...                15.0            2024-02-01
# 1      Software_Developper  ...                15.0            2024-02-01
# 2      Software_Developper  ...                15.0            2024-02-01
# 3      Software_Developper  ...                15.0            2024-02-01
# 4      Software_Developper  ...                15.0            2024-02-01
# ...                    ...  ...                 ...                   ...
# 59449           Consulting  ...                -3.0                  None
# 59450           Consulting  ...                -3.0                  None
# 59451  Software_Developper  ...                -3.0                  None
# 59452  Software_Developper  ...                -3.0                  None
# 59453           Consulting  ...                -3.0                  None
#
#        FEEDBACK_END_PERIOD    Q1    Q2    Q3    Q4    Q5    Q6  \
# 0               2024-02-08     3     4     4     1     2     3
# 1               2024-02-08     3     4     4     1     2     3
# 2               2024-02-08     3     4     4     1     2     3
# 3               2024-02-08     3     4     4     1     2     3
# 4               2024-02-08     3     4     4     1     2     3
# ...                    ...   ...   ...   ...   ...   ...   ...
# 59449                 None  None  None  None  None  None  None
# 59450                 None  None  None  None  None  None  None
# 59451                 None  None  None  None  None  None  None
# 59452                 None  None  None  None  None  None  None
# 59453                 None  None  None  None  None  None  None
#
#                                        FEEDBACK_COMMENTS
# 0      Struggling to cope with changing project requi...
# 1      Struggling to cope with changing project requi...
# 2      Struggling to cope with changing project requi...
# 3      Struggling to cope with changing project requi...
# 4      Struggling to cope with changing project requi...
# ...                                                  ...
# 59449                                               None
# 59450                                               None
# 59451                                               None
# 59452                                               None
# 59453                                               None
#
# [59454 rows x 40 columns]

# %%
threshold_hours = 35
df['ATTENDANCE_REGULARIZATION'] = (df['TOTAL_WEEK_HOURS'] < threshold_hours).astype(int)

# %%
df
# Out:
#       FIRST_NAME  LAST_NAME                 EMAIL  GENDER DOB_DD_MM_YYYY  \
# 0           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 1           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 2           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 3           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 4           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# ...          ...        ...                   ...     ...            ...
# 59449        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59450        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59451        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59452        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59453        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
#
#       USER_TYPE    ROLE  AGE                       CLIENT_NAME  \
# 0          User  intern   40  VonRueden, Bartell and Halvorson
# 1          User  intern   30                     Crist-Wiegand
# 2          User  intern   30                     Crist-Wiegand
# 3          User  intern   40  VonRueden, Bartell and Halvorson
# 4          User  intern   30  VonRueden, Bartell and Halvorson
# ...         ...     ...  ...                               ...
# 59449      User  intern   25                       Strosin Inc
# 59450      User  intern   25                       Strosin Inc
# 59451      User  intern   29                    Leannon-Grimes
# 59452      User  intern   29                    Leannon-Grimes
# 59453      User  intern   29                       Strosin Inc
#
#               PROJECT_NAME  ... FEEDBACK_START_PERIOD FEEDBACK_END_PERIOD  \
# 0      Software_Developper  ...            2024-02-01          2024-02-08
# 1      Software_Developper  ...            2024-02-01          2024-02-08
# 2      Software_Developper  ...            2024-02-01          2024-02-08
# 3      Software_Developper  ...            2024-02-01          2024-02-08
# 4      Software_Developper  ...            2024-02-01          2024-02-08
# ...                    ...  ...                   ...                 ...
# 59449           Consulting  ...                  None                None
# 59450           Consulting  ...                  None                None
# 59451  Software_Developper  ...                  None                None
# 59452  Software_Developper  ...                  None                None
# 59453           Consulting  ...                  None                None
#
#          Q1    Q2    Q3    Q4    Q5    Q6  \
# 0         3     4     4     1     2     3
# 1         3     4     4     1     2     3
# 2         3     4     4     1     2     3
# 3         3     4     4     1     2     3
# 4         3     4     4     1     2     3
# ...     ...   ...   ...   ...   ...   ...
# 59449  None  None  None  None  None  None
# 59450  None  None  None  None  None  None
# 59451  None  None  None  None  None  None
# 59452  None  None  None  None  None  None
# 59453  None  None  None  None  None  None
#
#                                        FEEDBACK_COMMENTS  \
# 0      Struggling to cope with changing project requi...
# 1      Struggling to cope with changing project requi...
# 2      Struggling to cope with changing project requi...
# 3      Struggling to cope with changing project requi...
# 4      Struggling to cope with changing project requi...
# ...                                                  ...
# 59449                                               None
# 59450                                               None
# 59451                                               None
# 59452                                               None
# 59453                                               None
#
#       ATTENDANCE_REGULARIZATION
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 59449                         0
# 59450                         0
# 59451                         0
# 59452                         0
# 59453                         0
#
# [59454 rows x 41 columns]

# %%
# Ensure 'ATTENDANCE_REGULARIZATION' is numerical
df['ATTENDANCE_REGULARIZATION'] = pd.to_numeric(df['ATTENDANCE_REGULARIZATION'], errors='coerce')

df_positive = df[df['ATTENDANCE_REGULARIZATION'] == 1].sample(n=2000, random_state=45)
df_negative = df[df['ATTENDANCE_REGULARIZATION'] == 0].sample(n=2000, random_state=45)
df_sampled = pd.concat([df_positive, df_negative])
df = df_sampled.sample(frac=1, random_state=42).reset_index(drop=True)
print(df['ATTENDANCE_REGULARIZATION'].value_counts())

df.to_csv('new_src_data.csv', index=False)
# Out:
# ATTENDANCE_REGULARIZATION
# 1    2000
# 0    2000
# Name: count, dtype: int64

# %%
file_path = 'new_src_data.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#   FIRST_NAME  LAST_NAME                         EMAIL  GENDER DOB_DD_MM_YYYY  \
# 0    Chiarra   Avrashin           cavrashin2p@fda.gov    Male     24-07-2000
# 1   Napoleon     Belfit      nbelfitnv@washington.edu    Male     21-04-1979
# 2     Tawsha    Paridge           tparidge7w@furl.net    Male     01-02-1988
# 3       Poul     Candey            pcandeykz@ebay.com  Female     18-07-1987
# 4        Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male     21-03-1991
#
#   USER_TYPE                 ROLE  AGE                 CLIENT_NAME  \
# 0      User  software_developper   24                Reynolds LLC
# 1      User               intern   45                 Gerlach LLC
# 2      User  software_developper   36   Keebler, Feil and Monahan
# 3      User           consultant   37                Cummings Inc
# 4      User               intern   33  Wyman, Langosh and Wiegand
#
#           PROJECT_NAME  ... FEEDBACK_START_PERIOD FEEDBACK_END_PERIOD   Q1  \
# 0  Software_Developper  ...                   NaN                 NaN  NaN
# 1  Software_Developper  ...                   NaN                 NaN  NaN
# 2  Software_Developper  ...            2023-11-23          2023-11-30  4.0
# 3           Consulting  ...            2024-02-09          2024-02-16  2.0
# 4  Software_Developper  ...            2023-04-19          2023-04-26  4.0
#
#     Q2   Q3   Q4   Q5   Q6                                  FEEDBACK_COMMENTS  \
# 0  NaN  NaN  NaN  NaN  NaN                                                NaN
# 1  NaN  NaN  NaN  NaN  NaN                                                NaN
# 2  1.0  5.0  1.0  3.0  2.0            Experiencing burnout due to long hours.
# 3  2.0  3.0  1.0  4.0  4.0  Feeling stressed due to the project's impact o...
# 4  4.0  3.0  5.0  4.0  2.0  Seeking guidance on managing project complexit...
#
#   ATTENDANCE_REGULARIZATION
# 0                         1
# 1                         0
# 2                         1
# 3                         0
# 4                         0
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FIRST_NAME                 4000 non-null   object
#  1   LAST_NAME                  4000 non-null   object
#  2   EMAIL                      4000 non-null   object
#  3   GENDER                     4000 non-null   object
#  4   DOB_DD_MM_YYYY             4000 non-null   object
#  5   USER_TYPE                  4000 non-null   object
#  6   ROLE                       4000 non-null   object
#  7   AGE                        4000 non-null   int64
#  8   CLIENT_NAME                4000 non-null   object
#  9   PROJECT_NAME               4000 non-null   object
#  10  PROJECT_START_DATE         4000 non-null   object
#  11  PROJECT_END_DATE           4000 non-null   object
#  12  PROJECT_DURATION           4000 non-null   int64
#  13  PROJECT_CATEGORY           4000 non-null   object
#  14  ALLOCATION_START           4000 non-null   object
#  15  ALLOCATION_END             4000 non-null   object
#  16  ALLOCATION_DURATION        4000 non-null   int64
#  17  WEEK_START                 3972 non-null   object
#  18  WEEK_END                   3972 non-null   object
#  19  ACTIVITY                   3972 non-null   object
#  20  COMMENTS                   3972 non-null   object
#  21  MON                        3972 non-null   float64
#  22  TUE                        3972 non-null   float64
#  23  WED                        3972 non-null   float64
#  24  THUR                       3972 non-null   float64
#  25  FRI                        3972 non-null   float64
#  26  SAT                        3972 non-null   float64
#  27  SUN                        3972 non-null   float64
#  28  FLAG                       3972 non-null   object
#  29  TOTAL_WEEK_HOURS           3972 non-null   float64
#  30  HOURS_OVER_OR_UNDER        3972 non-null   float64
#  31  FEEDBACK_START_PERIOD      2968 non-null   object
#  32  FEEDBACK_END_PERIOD        2968 non-null   object
#  33  Q1                         2968 non-null   float64
#  34  Q2                         2968 non-null   float64
#  35  Q3                         2968 non-null   float64
#  36  Q4                         2968 non-null   float64
#  37  Q5                         2968 non-null   float64
#  38  Q6                         2968 non-null   float64
#  39  FEEDBACK_COMMENTS          2968 non-null   object
#  40  ATTENDANCE_REGULARIZATION  4000 non-null   int64
# dtypes: float64(15), int64(4), object(22)
# memory usage: 1.3+ MB

# %% [markdown]
# # Uni-variate Analysis

# %%
#Count of users based on age groups

plt.figure(figsize=(8, 6))
sns.histplot(df['AGE'], bins=10, kde=True)
plt.title('Age Distribution of Users')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot project allocation duration distribution

plt.figure(figsize=(8, 6))
sns.histplot(df['ALLOCATION_DURATION'].dropna(), bins=10, kde=True)
plt.title('Project Allocation Duration Distribution')
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# plt.figure(figsize=(10, 6))
# sns.countplot(x='ROLE', data=df)
# plt.title('Distribution of Roles')
# plt.xlabel('Role')
# plt.ylabel('Count')
# plt.show()

# %%
#No of submissions based on the role

role_counts = df['ROLE'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=role_counts.index, y=role_counts.values)
plt.title('Number of Users Submitted based on Role')
plt.xlabel('Role')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate overall feedback score

feedback_columns = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']
df['FEEDBACK_SCORE'] = df[feedback_columns].mean(axis=1)
plt.figure(figsize=(10, 6))
sns.histplot(df['FEEDBACK_SCORE'], bins=10, kde=True)
plt.title('Distribution of Feedback Scores')
plt.xlabel('Feedback Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Analyzing feedback rating for each questions

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
feedback_questions = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']
for i, question in enumerate(feedback_questions):
    sns.histplot(df[question], ax=axes[i//3, i%3])
    axes[i//3, i%3].set_title(f'Distribution of {question}')
    axes[i//3, i%3].set_xlabel('Rating')
    axes[i//3, i%3].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Bi-variate Analysis

# %%
# Roles vs Project category based on the count

plt.figure(figsize=(10, 6))
sns.countplot(x='PROJECT_CATEGORY', hue='ROLE', data=df)
plt.title('Distribution of Roles by Project Category (Project Allocation Data)')
plt.xlabel('Project Category')
plt.ylabel('Count')
plt.legend(title='Role')
plt.show()

# %%
# Group the data by HOURS_OVER_OR_UNDER and calculate the mean of FEEDBACK_SCORE for each group

grouped_data = df.groupby('HOURS_OVER_OR_UNDER')['FEEDBACK_SCORE'].mean().reset_index()
plt.figure(figsize=(18, 8))
sns.barplot(x='HOURS_OVER_OR_UNDER', y='FEEDBACK_SCORE', data=grouped_data, palette='coolwarm')
plt.title('Average Feedback Score by Hours Over/Under')
plt.xlabel('Hours Over/Under')
plt.ylabel('Average Feedback Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Multi-variate Analysis

# %%
# Group the data by 'ROLE' and calculate the average 'FEEDBACK_SCORE' and 'HOURS_OVER_OR_UNDER'

grouped_data = df.groupby('ROLE').agg({'FEEDBACK_SCORE': 'mean', 'HOURS_OVER_OR_UNDER': 'mean'})
plt.figure(figsize=(12, 8))
grouped_data.plot(kind='bar', colormap='coolwarm')
plt.title('Average Feedback Score and Hours Over/Under by Role')
plt.xlabel('Role')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.legend(title='Metrics', loc='upper left')
plt.grid(axis='y')
plt.show()

# %%
# Load the data from the CSV file
df2 = pd.read_csv('src_data.csv')

# Group the data by age ranges (you may need to define your own age ranges)
df2['Age Group'] = pd.cut(df2['AGE'], bins=[0, 20, 30, 40, 50, 60, ], labels=['21-30', '31-40', '41-50', '51-60', '61-70'])

# Group the data by 'Age Group', calculate the mean of 'HOURS_OVER_OR_UNDER' and 'ALLOCATION_DURATION'
grouped_data = df2.groupby('Age Group')[['HOURS_OVER_OR_UNDER', 'ALLOCATION_DURATION']].mean().reset_index()

# Define the width of each bar
bar_width = 0.35

# Get the x-axis positions for the bars
x = np.arange(len(grouped_data))

# Plot bar chart for Allocation Duration
plt.figure(figsize=(12, 8))
plt.bar(x - bar_width/2, grouped_data['ALLOCATION_DURATION'], width=bar_width, color='orange', label='Allocation Duration (Mean)')

# Plot bar chart for Hours Over/Under
plt.bar(x + bar_width/2, grouped_data['HOURS_OVER_OR_UNDER'], width=bar_width, color='skyblue', label='Hours Over/Under (Mean)')

plt.title('Comparison of Hours Over/Under and Allocation Duration by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Mean Value')
plt.xticks(x, grouped_data['Age Group'])  # Set x-axis tick labels
plt.legend()
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\AadishNagarajan\AppData\Local\Temp\ipykernel_13260\1010698776.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df2.groupby('Age Group')[['HOURS_OVER_OR_UNDER', 'ALLOCATION_DURATION']].mean().reset_index()

# %%
df
# Out:
#      FIRST_NAME  LAST_NAME                         EMAIL  GENDER  \
# 0       Chiarra   Avrashin           cavrashin2p@fda.gov    Male
# 1      Napoleon     Belfit      nbelfitnv@washington.edu    Male
# 2        Tawsha    Paridge           tparidge7w@furl.net    Male
# 3          Poul     Candey            pcandeykz@ebay.com  Female
# 4           Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# ...         ...        ...                           ...     ...
# 3995    Allison   Reinbach        areinbach8c@unicef.org    Male
# 3996      Maddy    Fendley          mfendley9n@chron.com  Female
# 3997    Hermina     Musker           hmuskermu@google.ca    Male
# 3998        Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# 3999      Briny    Kittman         bkittmannd@dyndns.org    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        24-07-2000      User  software_developper   24
# 1        21-04-1979      User               intern   45
# 2        01-02-1988      User  software_developper   36
# 3        18-07-1987      User           consultant   37
# 4        21-03-1991      User               intern   33
# ...             ...       ...                  ...  ...
# 3995     20-09-1990      User               intern   34
# 3996     26-07-1988      User           consultant   36
# 3997     25-08-1977      User         tribe_master   47
# 3998     03-09-1978      User               intern   46
# 3999     04-09-1983      User         tribe_master   41
#
#                      CLIENT_NAME         PROJECT_NAME  ...  \
# 0                   Reynolds LLC  Software_Developper  ...
# 1                    Gerlach LLC  Software_Developper  ...
# 2      Keebler, Feil and Monahan  Software_Developper  ...
# 3                   Cummings Inc           Consulting  ...
# 4     Wyman, Langosh and Wiegand  Software_Developper  ...
# ...                          ...                  ...  ...
# 3995    Crist, Harvey and Heaney  Software_Developper  ...
# 3996   Trantow, Bednar and Hills           Consulting  ...
# 3997  Heaney, Wyman and Gorczany  Software_Developper  ...
# 3998  Wyman, Langosh and Wiegand  Software_Developper  ...
# 3999            Stanton and Sons  Software_Developper  ...
#
#      FEEDBACK_END_PERIOD   Q1   Q2   Q3   Q4   Q5   Q6  \
# 0                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2             2023-11-30  4.0  1.0  5.0  1.0  3.0  2.0
# 3             2024-02-16  2.0  2.0  3.0  1.0  4.0  4.0
# 4             2023-04-26  4.0  4.0  3.0  5.0  4.0  2.0
# ...                  ...  ...  ...  ...  ...  ...  ...
# 3995          2024-01-18  2.0  1.0  2.0  2.0  5.0  3.0
# 3996          2024-03-07  3.0  3.0  1.0  3.0  4.0  3.0
# 3997          2023-08-16  5.0  4.0  4.0  5.0  3.0  4.0
# 3998          2023-05-03  4.0  4.0  4.0  1.0  2.0  4.0
# 3999          2024-01-25  1.0  2.0  4.0  4.0  2.0  3.0
#
#                                       FEEDBACK_COMMENTS  \
# 0                                                   NaN
# 1                                                   NaN
# 2               Experiencing burnout due to long hours.
# 3     Feeling stressed due to the project's impact o...
# 4     Seeking guidance on managing project complexit...
# ...                                                 ...
# 3995  Experiencing difficulties in managing project ...
# 3996  Struggling with maintaining project stakeholde...
# 3997  Struggling to balance multiple projects simult...
# 3998            Concerns about the project's direction.
# 3999      Concerns about the team's communication gaps.
#
#      ATTENDANCE_REGULARIZATION FEEDBACK_SCORE
# 0                            1            NaN
# 1                            0            NaN
# 2                            1       2.666667
# 3                            0       2.666667
# 4                            0       3.666667
# ...                        ...            ...
# 3995                         1       2.500000
# 3996                         1       2.833333
# 3997                         1       4.166667
# 3998                         0       3.166667
# 3999                         0       2.666667
#
# [4000 rows x 42 columns]

# %% [markdown]
# # Feature Engineering

# %%
# Split date fields into day, month, and year and add them as new columns
date_columns = ["DOB_DD_MM_YYYY", "PROJECT_START_DATE", "PROJECT_END_DATE", "ALLOCATION_START", "ALLOCATION_END", "WEEK_START", "WEEK_END", "FEEDBACK_START_PERIOD", "FEEDBACK_END_PERIOD"]

# Convert date columns to string type
df[date_columns] = df[date_columns].astype(str)
for column in date_columns:
    # Split the date string into day, month, and year components
    split_date = df[column].str.split('-', n=2, expand=True)
    df[column + '_DAY'] = split_date[0]
    df[column + '_MONTH'] = split_date[1]
    df[column + '_YEAR'] = split_date[2]

print(df)
# Out:
#      FIRST_NAME  LAST_NAME                         EMAIL  GENDER  \
# 0       Chiarra   Avrashin           cavrashin2p@fda.gov    Male
# 1      Napoleon     Belfit      nbelfitnv@washington.edu    Male
# 2        Tawsha    Paridge           tparidge7w@furl.net    Male
# 3          Poul     Candey            pcandeykz@ebay.com  Female
# 4           Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# ...         ...        ...                           ...     ...
# 3995    Allison   Reinbach        areinbach8c@unicef.org    Male
# 3996      Maddy    Fendley          mfendley9n@chron.com  Female
# 3997    Hermina     Musker           hmuskermu@google.ca    Male
# 3998        Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# 3999      Briny    Kittman         bkittmannd@dyndns.org    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        24-07-2000      User  software_developper   24
# 1        21-04-1979      User               intern   45
# 2        01-02-1988      User  software_developper   36
# 3        18-07-1987      User           consultant   37
# 4        21-03-1991      User               intern   33
# ...             ...       ...                  ...  ...
# 3995     20-09-1990      User               intern   34
# 3996     26-07-1988      User           consultant   36
# 3997     25-08-1977      User         tribe_master   47
# 3998     03-09-1978      User               intern   46
# 3999     04-09-1983      User         tribe_master   41
#
#                      CLIENT_NAME         PROJECT_NAME  ... WEEK_START_YEAR  \
# 0                   Reynolds LLC  Software_Developper  ...              31
# 1                    Gerlach LLC  Software_Developper  ...              21
# 2      Keebler, Feil and Monahan  Software_Developper  ...              18
# 3                   Cummings Inc           Consulting  ...              06
# 4     Wyman, Langosh and Wiegand  Software_Developper  ...              11
# ...                          ...                  ...  ...             ...
# 3995    Crist, Harvey and Heaney  Software_Developper  ...              11
# 3996   Trantow, Bednar and Hills           Consulting  ...              31
# 3997  Heaney, Wyman and Gorczany  Software_Developper  ...              29
# 3998  Wyman, Langosh and Wiegand  Software_Developper  ...              02
# 3999            Stanton and Sons  Software_Developper  ...              31
#
#      WEEK_END_DAY  WEEK_END_MONTH WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0            2024              02            07                       nan
# 1            2023              11            28                       nan
# 2            2023              12            25                      2023
# 3            2024              03            13                      2024
# 4            2024              01            18                      2023
# ...           ...             ...           ...                       ...
# 3995         2024              01            18                      2024
# 3996         2023              06            07                      2024
# 3997         2023              11            05                      2023
# 3998         2023              12            09                      2023
# 3999         2024              02            07                      2024
#
#      FEEDBACK_START_PERIOD_MONTH  FEEDBACK_START_PERIOD_YEAR  \
# 0                           None                        None
# 1                           None                        None
# 2                             11                          23
# 3                             02                          09
# 4                             04                          19
# ...                          ...                         ...
# 3995                          01                          11
# 3996                          02                          29
# 3997                          08                          09
# 3998                          04                          26
# 3999                          01                          18
#
#      FEEDBACK_END_PERIOD_DAY FEEDBACK_END_PERIOD_MONTH  \
# 0                        nan                      None
# 1                        nan                      None
# 2                       2023                        11
# 3                       2024                        02
# 4                       2023                        04
# ...                      ...                       ...
# 3995                    2024                        01
# 3996                    2024                        03
# 3997                    2023                        08
# 3998                    2023                        05
# 3999                    2024                        01
#
#      FEEDBACK_END_PERIOD_YEAR
# 0                        None
# 1                        None
# 2                          30
# 3                          16
# 4                          26
# ...                       ...
# 3995                       18
# 3996                       07
# 3997                       16
# 3998                       03
# 3999                       25
#
# [4000 rows x 69 columns]

# %%
df
# Out:
#      FIRST_NAME  LAST_NAME                         EMAIL  GENDER  \
# 0       Chiarra   Avrashin           cavrashin2p@fda.gov    Male
# 1      Napoleon     Belfit      nbelfitnv@washington.edu    Male
# 2        Tawsha    Paridge           tparidge7w@furl.net    Male
# 3          Poul     Candey            pcandeykz@ebay.com  Female
# 4           Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# ...         ...        ...                           ...     ...
# 3995    Allison   Reinbach        areinbach8c@unicef.org    Male
# 3996      Maddy    Fendley          mfendley9n@chron.com  Female
# 3997    Hermina     Musker           hmuskermu@google.ca    Male
# 3998        Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# 3999      Briny    Kittman         bkittmannd@dyndns.org    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        24-07-2000      User  software_developper   24
# 1        21-04-1979      User               intern   45
# 2        01-02-1988      User  software_developper   36
# 3        18-07-1987      User           consultant   37
# 4        21-03-1991      User               intern   33
# ...             ...       ...                  ...  ...
# 3995     20-09-1990      User               intern   34
# 3996     26-07-1988      User           consultant   36
# 3997     25-08-1977      User         tribe_master   47
# 3998     03-09-1978      User               intern   46
# 3999     04-09-1983      User         tribe_master   41
#
#                      CLIENT_NAME         PROJECT_NAME  ... WEEK_START_YEAR  \
# 0                   Reynolds LLC  Software_Developper  ...              31
# 1                    Gerlach LLC  Software_Developper  ...              21
# 2      Keebler, Feil and Monahan  Software_Developper  ...              18
# 3                   Cummings Inc           Consulting  ...              06
# 4     Wyman, Langosh and Wiegand  Software_Developper  ...              11
# ...                          ...                  ...  ...             ...
# 3995    Crist, Harvey and Heaney  Software_Developper  ...              11
# 3996   Trantow, Bednar and Hills           Consulting  ...              31
# 3997  Heaney, Wyman and Gorczany  Software_Developper  ...              29
# 3998  Wyman, Langosh and Wiegand  Software_Developper  ...              02
# 3999            Stanton and Sons  Software_Developper  ...              31
#
#      WEEK_END_DAY  WEEK_END_MONTH WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0            2024              02            07                       nan
# 1            2023              11            28                       nan
# 2            2023              12            25                      2023
# 3            2024              03            13                      2024
# 4            2024              01            18                      2023
# ...           ...             ...           ...                       ...
# 3995         2024              01            18                      2024
# 3996         2023              06            07                      2024
# 3997         2023              11            05                      2023
# 3998         2023              12            09                      2023
# 3999         2024              02            07                      2024
#
#      FEEDBACK_START_PERIOD_MONTH  FEEDBACK_START_PERIOD_YEAR  \
# 0                           None                        None
# 1                           None                        None
# 2                             11                          23
# 3                             02                          09
# 4                             04                          19
# ...                          ...                         ...
# 3995                          01                          11
# 3996                          02                          29
# 3997                          08                          09
# 3998                          04                          26
# 3999                          01                          18
#
#      FEEDBACK_END_PERIOD_DAY FEEDBACK_END_PERIOD_MONTH  \
# 0                        nan                      None
# 1                        nan                      None
# 2                       2023                        11
# 3                       2024                        02
# 4                       2023                        04
# ...                      ...                       ...
# 3995                    2024                        01
# 3996                    2024                        03
# 3997                    2023                        08
# 3998                    2023                        05
# 3999                    2024                        01
#
#      FEEDBACK_END_PERIOD_YEAR
# 0                        None
# 1                        None
# 2                          30
# 3                          16
# 4                          26
# ...                       ...
# 3995                       18
# 3996                       07
# 3997                       16
# 3998                       03
# 3999                       25
#
# [4000 rows x 69 columns]

# %%
# Drop rows with NaN values
df.dropna(inplace=True)
print(df)
# Out:
#      FIRST_NAME  LAST_NAME                         EMAIL  GENDER  \
# 2        Tawsha    Paridge           tparidge7w@furl.net    Male
# 3          Poul     Candey            pcandeykz@ebay.com  Female
# 4           Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# 5        Kirbee   Rosiello      krosielloqr@symantec.com  Female
# 6        Jarvis      Arter        jartermc@google.com.br  Female
# ...         ...        ...                           ...     ...
# 3995    Allison   Reinbach        areinbach8c@unicef.org    Male
# 3996      Maddy    Fendley          mfendley9n@chron.com  Female
# 3997    Hermina     Musker           hmuskermu@google.ca    Male
# 3998        Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male
# 3999      Briny    Kittman         bkittmannd@dyndns.org    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 2        01-02-1988      User  software_developper   36
# 3        18-07-1987      User           consultant   37
# 4        21-03-1991      User               intern   33
# 5        02-07-1979      User         tribe_master   45
# 6        01-04-2001      User  software_developper   23
# ...             ...       ...                  ...  ...
# 3995     20-09-1990      User               intern   34
# 3996     26-07-1988      User           consultant   36
# 3997     25-08-1977      User         tribe_master   47
# 3998     03-09-1978      User               intern   46
# 3999     04-09-1983      User         tribe_master   41
#
#                         CLIENT_NAME         PROJECT_NAME  ... WEEK_START_YEAR  \
# 2         Keebler, Feil and Monahan  Software_Developper  ...              18
# 3                      Cummings Inc           Consulting  ...              06
# 4        Wyman, Langosh and Wiegand  Software_Developper  ...              11
# 5                        Ledner LLC  Software_Developper  ...              10
# 6     Walker, Williamson and Reilly  Software_Developper  ...              18
# ...                             ...                  ...  ...             ...
# 3995       Crist, Harvey and Heaney  Software_Developper  ...              11
# 3996      Trantow, Bednar and Hills           Consulting  ...              31
# 3997     Heaney, Wyman and Gorczany  Software_Developper  ...              29
# 3998     Wyman, Langosh and Wiegand  Software_Developper  ...              02
# 3999               Stanton and Sons  Software_Developper  ...              31
#
#      WEEK_END_DAY  WEEK_END_MONTH WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 2            2023              12            25                      2023
# 3            2024              03            13                      2024
# 4            2024              01            18                      2023
# 5            2024              02            17                      2024
# 6            2023              12            25                      2023
# ...           ...             ...           ...                       ...
# 3995         2024              01            18                      2024
# 3996         2023              06            07                      2024
# 3997         2023              11            05                      2023
# 3998         2023              12            09                      2023
# 3999         2024              02            07                      2024
#
#      FEEDBACK_START_PERIOD_MONTH  FEEDBACK_START_PERIOD_YEAR  \
# 2                             11                          23
# 3                             02                          09
# 4                             04                          19
# 5                             01                          31
# 6                             09                          13
# ...                          ...                         ...
# 3995                          01                          11
# 3996                          02                          29
# 3997                          08                          09
# 3998                          04                          26
# 3999                          01                          18
#
#      FEEDBACK_END_PERIOD_DAY FEEDBACK_END_PERIOD_MONTH  \
# 2                       2023                        11
# 3                       2024                        02
# 4                       2023                        04
# 5                       2024                        02
# 6                       2023                        09
# ...                      ...                       ...
# 3995                    2024                        01
# 3996                    2024                        03
# 3997                    2023                        08
# 3998                    2023                        05
# 3999                    2024                        01
#
#      FEEDBACK_END_PERIOD_YEAR
# 2                          30
# 3                          16
# 4                          26
# 5                          07
# 6                          20
# ...                       ...
# 3995                       18
# 3996                       07
# 3997                       16
# 3998                       03
# 3999                       25
#
# [2945 rows x 69 columns]

# %%
# Specify the columns to be dropped
columns_to_drop = ['DOB_DD_MM_YYYY', 'ALLOCATION_START', 'ALLOCATION_END', 'FEEDBACK_START_PERIOD', 'FEEDBACK_END_PERIOD']
df.drop(columns=columns_to_drop, inplace=True)
df
# Out:
#      FIRST_NAME  LAST_NAME                         EMAIL  GENDER USER_TYPE  \
# 2        Tawsha    Paridge           tparidge7w@furl.net    Male      User
# 3          Poul     Candey            pcandeykz@ebay.com  Female      User
# 4           Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male      User
# 5        Kirbee   Rosiello      krosielloqr@symantec.com  Female      User
# 6        Jarvis      Arter        jartermc@google.com.br  Female      User
# ...         ...        ...                           ...     ...       ...
# 3995    Allison   Reinbach        areinbach8c@unicef.org    Male      User
# 3996      Maddy    Fendley          mfendley9n@chron.com  Female      User
# 3997    Hermina     Musker           hmuskermu@google.ca    Male      User
# 3998        Dal  MacAleese  dmacaleeserm@cyberchimps.com    Male      User
# 3999      Briny    Kittman         bkittmannd@dyndns.org    Male      User
#
#                      ROLE  AGE                    CLIENT_NAME  \
# 2     software_developper   36      Keebler, Feil and Monahan
# 3              consultant   37                   Cummings Inc
# 4                  intern   33     Wyman, Langosh and Wiegand
# 5            tribe_master   45                     Ledner LLC
# 6     software_developper   23  Walker, Williamson and Reilly
# ...                   ...  ...                            ...
# 3995               intern   34       Crist, Harvey and Heaney
# 3996           consultant   36      Trantow, Bednar and Hills
# 3997         tribe_master   47     Heaney, Wyman and Gorczany
# 3998               intern   46     Wyman, Langosh and Wiegand
# 3999         tribe_master   41               Stanton and Sons
#
#              PROJECT_NAME PROJECT_START_DATE  ... WEEK_START_YEAR  \
# 2     Software_Developper         2023-05-02  ...              18
# 3              Consulting         2024-03-18  ...              06
# 4     Software_Developper         2023-08-11  ...              11
# 5     Software_Developper         2023-10-30  ...              10
# 6     Software_Developper         2023-04-22  ...              18
# ...                   ...                ...  ...             ...
# 3995  Software_Developper         2023-08-19  ...              11
# 3996           Consulting         2023-12-07  ...              31
# 3997  Software_Developper         2023-09-16  ...              29
# 3998  Software_Developper         2023-08-11  ...              02
# 3999  Software_Developper         2024-03-19  ...              31
#
#       WEEK_END_DAY WEEK_END_MONTH  WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 2             2023             12             25                      2023
# 3             2024             03             13                      2024
# 4             2024             01             18                      2023
# 5             2024             02             17                      2024
# 6             2023             12             25                      2023
# ...            ...            ...            ...                       ...
# 3995          2024             01             18                      2024
# 3996          2023             06             07                      2024
# 3997          2023             11             05                      2023
# 3998          2023             12             09                      2023
# 3999          2024             02             07                      2024
#
#      FEEDBACK_START_PERIOD_MONTH FEEDBACK_START_PERIOD_YEAR  \
# 2                             11                         23
# 3                             02                         09
# 4                             04                         19
# 5                             01                         31
# 6                             09                         13
# ...                          ...                        ...
# 3995                          01                         11
# 3996                          02                         29
# 3997                          08                         09
# 3998                          04                         26
# 3999                          01                         18
#
#      FEEDBACK_END_PERIOD_DAY  FEEDBACK_END_PERIOD_MONTH  \
# 2                       2023                         11
# 3                       2024                         02
# 4                       2023                         04
# 5                       2024                         02
# 6                       2023                         09
# ...                      ...                        ...
# 3995                    2024                         01
# 3996                    2024                         03
# 3997                    2023                         08
# 3998                    2023                         05
# 3999                    2024                         01
#
#       FEEDBACK_END_PERIOD_YEAR
# 2                           30
# 3                           16
# 4                           26
# 5                           07
# 6                           20
# ...                        ...
# 3995                        18
# 3996                        07
# 3997                        16
# 3998                        03
# 3999                        25
#
# [2945 rows x 64 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2945 entries, 2 to 3999
# Data columns (total 64 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   FIRST_NAME                   2945 non-null   object
#  1   LAST_NAME                    2945 non-null   object
#  2   EMAIL                        2945 non-null   object
#  3   GENDER                       2945 non-null   object
#  4   USER_TYPE                    2945 non-null   object
#  5   ROLE                         2945 non-null   object
#  6   AGE                          2945 non-null   int64
#  7   CLIENT_NAME                  2945 non-null   object
#  8   PROJECT_NAME                 2945 non-null   object
#  9   PROJECT_START_DATE           2945 non-null   object
#  10  PROJECT_END_DATE             2945 non-null   object
#  11  PROJECT_DURATION             2945 non-null   int64
#  12  PROJECT_CATEGORY             2945 non-null   object
#  13  ALLOCATION_DURATION          2945 non-null   int64
#  14  WEEK_START                   2945 non-null   object
#  15  WEEK_END                     2945 non-null   object
#  16  ACTIVITY                     2945 non-null   object
#  17  COMMENTS                     2945 non-null   object
#  18  MON                          2945 non-null   float64
#  19  TUE                          2945 non-null   float64
#  20  WED                          2945 non-null   float64
#  21  THUR                         2945 non-null   float64
#  22  FRI                          2945 non-null   float64
#  23  SAT                          2945 non-null   float64
#  24  SUN                          2945 non-null   float64
#  25  FLAG                         2945 non-null   object
#  26  TOTAL_WEEK_HOURS             2945 non-null   float64
#  27  HOURS_OVER_OR_UNDER          2945 non-null   float64
#  28  Q1                           2945 non-null   float64
#  29  Q2                           2945 non-null   float64
#  30  Q3                           2945 non-null   float64
#  31  Q4                           2945 non-null   float64
#  32  Q5                           2945 non-null   float64
#  33  Q6                           2945 non-null   float64
#  34  FEEDBACK_COMMENTS            2945 non-null   object
#  35  ATTENDANCE_REGULARIZATION    2945 non-null   int64
#  36  FEEDBACK_SCORE               2945 non-null   float64
#  37  DOB_DD_MM_YYYY_DAY           2945 non-null   object
#  38  DOB_DD_MM_YYYY_MONTH         2945 non-null   object
#  39  DOB_DD_MM_YYYY_YEAR          2945 non-null   object
#  40  PROJECT_START_DATE_DAY       2945 non-null   object
#  41  PROJECT_START_DATE_MONTH     2945 non-null   object
#  42  PROJECT_START_DATE_YEAR      2945 non-null   object
#  43  PROJECT_END_DATE_DAY         2945 non-null   object
#  44  PROJECT_END_DATE_MONTH       2945 non-null   object
#  45  PROJECT_END_DATE_YEAR        2945 non-null   object
#  46  ALLOCATION_START_DAY         2945 non-null   object
#  47  ALLOCATION_START_MONTH       2945 non-null   object
#  48  ALLOCATION_START_YEAR        2945 non-null   object
#  49  ALLOCATION_END_DAY           2945 non-null   object
#  50  ALLOCATION_END_MONTH         2945 non-null   object
#  51  ALLOCATION_END_YEAR          2945 non-null   object
#  52  WEEK_START_DAY               2945 non-null   object
#  53  WEEK_START_MONTH             2945 non-null   object
#  54  WEEK_START_YEAR              2945 non-null   object
#  55  WEEK_END_DAY                 2945 non-null   object
#  56  WEEK_END_MONTH               2945 non-null   object
#  57  WEEK_END_YEAR                2945 non-null   object
#  58  FEEDBACK_START_PERIOD_DAY    2945 non-null   object
#  59  FEEDBACK_START_PERIOD_MONTH  2945 non-null   object
#  60  FEEDBACK_START_PERIOD_YEAR   2945 non-null   object
#  61  FEEDBACK_END_PERIOD_DAY      2945 non-null   object
#  62  FEEDBACK_END_PERIOD_MONTH    2945 non-null   object
#  63  FEEDBACK_END_PERIOD_YEAR     2945 non-null   object
# dtypes: float64(16), int64(4), object(44)
# memory usage: 1.5+ MB

# %%
columns_to_drop = ['FIRST_NAME', 'LAST_NAME','GENDER','FLAG','EMAIL','USER_TYPE','COMMENTS','AGE','DOB_DD_MM_YYYY_MONTH','DOB_DD_MM_YYYY_YEAR','DOB_DD_MM_YYYY_DAY', 'CLIENT_NAME', 'PROJECT_START_DATE', 'PROJECT_END_DATE','FEEDBACK_COMMENTS','WEEK_START','WEEK_END','FEEDBACK_START_PERIOD_DAY','FEEDBACK_START_PERIOD_MONTH','FEEDBACK_START_PERIOD_YEAR','FEEDBACK_END_PERIOD_DAY','FEEDBACK_END_PERIOD_MONTH','FEEDBACK_END_PERIOD_YEAR','Q1','Q2','Q3','Q4','Q5','Q6']
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#                   ROLE         PROJECT_NAME  PROJECT_DURATION  \
# 2  software_developper  Software_Developper                35
# 3           consultant           Consulting                35
# 4               intern  Software_Developper                35
# 5         tribe_master  Software_Developper                28
# 6  software_developper  Software_Developper                14
#
#     PROJECT_CATEGORY  ALLOCATION_DURATION        ACTIVITY  MON  TUE  WED  \
# 2    Mid Cap Project                   14  sales_activity  6.0  6.0  1.0
# 3    Mid Cap Project                   42  sales_activity  2.0  8.0  1.0
# 4    Mid Cap Project                   28  sales_activity  7.0  2.0  8.0
# 5    Mid Cap Project                   28  client_project  9.0  5.0  4.0
# 6  Small Cap Project                   42             bau  9.0  7.0  2.0
#
#    THUR  ...  ALLOCATION_START_YEAR  ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# 2   3.0  ...                   2024                  19                    03
# 3  11.0  ...                   2024                  01                    03
# 4   3.0  ...                   2023                  06                    11
# 5   3.0  ...                   2023                  12                    11
# 6   4.0  ...                   2023                  19                    10
#
#    ALLOCATION_END_YEAR  WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  \
# 2                 2024            2023                12               18
# 3                 2024            2024                03               06
# 4                 2023            2024                01               11
# 5                 2023            2024                02               10
# 6                 2023            2023                12               18
#
#   WEEK_END_DAY WEEK_END_MONTH WEEK_END_YEAR
# 2         2023             12            25
# 3         2024             03            13
# 4         2024             01            18
# 5         2024             02            17
# 6         2023             12            25
#
# [5 rows x 35 columns]

# %%
from sklearn.preprocessing import LabelEncoder

#Data Encoding

# Initialize LabelEncoder
label_encoder = LabelEncoder()

df['ROLE'] = label_encoder.fit_transform(df['ROLE'])
df['PROJECT_NAME'] = label_encoder.fit_transform(df['PROJECT_NAME'])

# Display the DataFrame after conversion
df.head()
# Out:
#    ROLE  PROJECT_NAME  PROJECT_DURATION   PROJECT_CATEGORY  \
# 2     2             2                35    Mid Cap Project
# 3     0             0                35    Mid Cap Project
# 4     1             2                35    Mid Cap Project
# 5     3             2                28    Mid Cap Project
# 6     2             2                14  Small Cap Project
#
#    ALLOCATION_DURATION        ACTIVITY  MON  TUE  WED  THUR  ...  \
# 2                   14  sales_activity  6.0  6.0  1.0   3.0  ...
# 3                   42  sales_activity  2.0  8.0  1.0  11.0  ...
# 4                   28  sales_activity  7.0  2.0  8.0   3.0  ...
# 5                   28  client_project  9.0  5.0  4.0   3.0  ...
# 6                   42             bau  9.0  7.0  2.0   4.0  ...
#
#    ALLOCATION_START_YEAR  ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# 2                   2024                  19                    03
# 3                   2024                  01                    03
# 4                   2023                  06                    11
# 5                   2023                  12                    11
# 6                   2023                  19                    10
#
#    ALLOCATION_END_YEAR  WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  \
# 2                 2024            2023                12               18
# 3                 2024            2024                03               06
# 4                 2023            2024                01               11
# 5                 2023            2024                02               10
# 6                 2023            2023                12               18
#
#   WEEK_END_DAY WEEK_END_MONTH WEEK_END_YEAR
# 2         2023             12            25
# 3         2024             03            13
# 4         2024             01            18
# 5         2024             02            17
# 6         2023             12            25
#
# [5 rows x 35 columns]

# %%
df
# Out:
#       ROLE  PROJECT_NAME  PROJECT_DURATION   PROJECT_CATEGORY  \
# 2        2             2                35    Mid Cap Project
# 3        0             0                35    Mid Cap Project
# 4        1             2                35    Mid Cap Project
# 5        3             2                28    Mid Cap Project
# 6        2             2                14  Small Cap Project
# ...    ...           ...               ...                ...
# 3995     1             2                35    Mid Cap Project
# 3996     0             0                14  Small Cap Project
# 3997     3             2                42    Mid Cap Project
# 3998     1             2                35    Mid Cap Project
# 3999     3             2                35    Mid Cap Project
#
#       ALLOCATION_DURATION        ACTIVITY  MON   TUE   WED  THUR  ...  \
# 2                      14  sales_activity  6.0   6.0   1.0   3.0  ...
# 3                      42  sales_activity  2.0   8.0   1.0  11.0  ...
# 4                      28  sales_activity  7.0   2.0   8.0   3.0  ...
# 5                      28  client_project  9.0   5.0   4.0   3.0  ...
# 6                      42             bau  9.0   7.0   2.0   4.0  ...
# ...                   ...             ...  ...   ...   ...   ...  ...
# 3995                   28  client_project  5.0   5.0   3.0  10.0  ...
# 3996                   21  sales_activity  3.0   5.0  12.0   2.0  ...
# 3997                   42             bau  1.0  11.0   3.0   5.0  ...
# 3998                   28  client_project  1.0  12.0   6.0   7.0  ...
# 3999                   42             bau  4.0   8.0   3.0   5.0  ...
#
#       ALLOCATION_START_YEAR  ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# 2                      2024                  19                    03
# 3                      2024                  01                    03
# 4                      2023                  06                    11
# 5                      2023                  12                    11
# 6                      2023                  19                    10
# ...                     ...                 ...                   ...
# 3995                   2023                  23                    11
# 3996                   2023                  21                    12
# 3997                   2024                  25                    04
# 3998                   2023                  06                    11
# 3999                   2024                  04                    05
#
#       ALLOCATION_END_YEAR  WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  \
# 2                    2024            2023                12               18
# 3                    2024            2024                03               06
# 4                    2023            2024                01               11
# 5                    2023            2024                02               10
# 6                    2023            2023                12               18
# ...                   ...             ...               ...              ...
# 3995                 2023            2024                01               11
# 3996                 2023            2023                05               31
# 3997                 2024            2023                10               29
# 3998                 2023            2023                12               02
# 3999                 2024            2024                01               31
#
#      WEEK_END_DAY WEEK_END_MONTH WEEK_END_YEAR
# 2            2023             12            25
# 3            2024             03            13
# 4            2024             01            18
# 5            2024             02            17
# 6            2023             12            25
# ...           ...            ...           ...
# 3995         2024             01            18
# 3996         2023             06            07
# 3997         2023             11            05
# 3998         2023             12            09
# 3999         2024             02            07
#
# [2945 rows x 35 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['project_category'] = label_encoder.fit_transform(df['PROJECT_CATEGORY'])

# Show the updated DataFrame
print(df)
# Out:
#       ROLE  PROJECT_NAME  PROJECT_DURATION   PROJECT_CATEGORY  \
# 2        2             2                35    Mid Cap Project
# 3        0             0                35    Mid Cap Project
# 4        1             2                35    Mid Cap Project
# 5        3             2                28    Mid Cap Project
# 6        2             2                14  Small Cap Project
# ...    ...           ...               ...                ...
# 3995     1             2                35    Mid Cap Project
# 3996     0             0                14  Small Cap Project
# 3997     3             2                42    Mid Cap Project
# 3998     1             2                35    Mid Cap Project
# 3999     3             2                35    Mid Cap Project
#
#       ALLOCATION_DURATION        ACTIVITY  MON   TUE   WED  THUR  ...  \
# 2                      14  sales_activity  6.0   6.0   1.0   3.0  ...
# 3                      42  sales_activity  2.0   8.0   1.0  11.0  ...
# 4                      28  sales_activity  7.0   2.0   8.0   3.0  ...
# 5                      28  client_project  9.0   5.0   4.0   3.0  ...
# 6                      42             bau  9.0   7.0   2.0   4.0  ...
# ...                   ...             ...  ...   ...   ...   ...  ...
# 3995                   28  client_project  5.0   5.0   3.0  10.0  ...
# 3996                   21  sales_activity  3.0   5.0  12.0   2.0  ...
# 3997                   42             bau  1.0  11.0   3.0   5.0  ...
# 3998                   28  client_project  1.0  12.0   6.0   7.0  ...
# 3999                   42             bau  4.0   8.0   3.0   5.0  ...
#
#       ALLOCATION_END_DAY  ALLOCATION_END_MONTH  ALLOCATION_END_YEAR  \
# 2                     19                    03                 2024
# 3                     01                    03                 2024
# 4                     06                    11                 2023
# 5                     12                    11                 2023
# 6                     19                    10                 2023
# ...                  ...                   ...                  ...
# 3995                  23                    11                 2023
# 3996                  21                    12                 2023
# 3997                  25                    04                 2024
# 3998                  06                    11                 2023
# 3999                  04                    05                 2024
#
#       WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  \
# 2               2023                12               18          2023
# 3               2024                03               06          2024
# 4               2024                01               11          2024
# 5               2024                02               10          2024
# 6               2023                12               18          2023
# ...              ...               ...              ...           ...
# 3995            2024                01               11          2024
# 3996            2023                05               31          2023
# 3997            2023                10               29          2023
# 3998            2023                12               02          2023
# 3999            2024                01               31          2024
#
#      WEEK_END_MONTH WEEK_END_YEAR project_category
# 2                12            25                0
# 3                03            13                0
# 4                01            18                0
# 5                02            17                0
# 6                12            25                1
# ...             ...           ...              ...
# 3995             01            18                0
# 3996             06            07                1
# 3997             11            05                0
# 3998             12            09                0
# 3999             02            07                0
#
# [2945 rows x 36 columns]

# %%
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].astype('category')
df['ROLE'] = df['ROLE'].astype('int64')
df['PROJECT_CATEGORY'] = df['PROJECT_CATEGORY'].astype('category')

# Display the updated DataFrame info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2945 entries, 2 to 3999
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ROLE                       2945 non-null   int64
#  1   PROJECT_NAME               2945 non-null   int32
#  2   PROJECT_DURATION           2945 non-null   int64
#  3   PROJECT_CATEGORY           2945 non-null   category
#  4   ALLOCATION_DURATION        2945 non-null   int64
#  5   ACTIVITY                   2945 non-null   category
#  6   MON                        2945 non-null   float64
#  7   TUE                        2945 non-null   float64
#  8   WED                        2945 non-null   float64
#  9   THUR                       2945 non-null   float64
#  10  FRI                        2945 non-null   float64
#  11  SAT                        2945 non-null   float64
#  12  SUN                        2945 non-null   float64
#  13  TOTAL_WEEK_HOURS           2945 non-null   float64
#  14  HOURS_OVER_OR_UNDER        2945 non-null   float64
#  15  ATTENDANCE_REGULARIZATION  2945 non-null   int64
#  16  FEEDBACK_SCORE             2945 non-null   float64
#  17  PROJECT_START_DATE_DAY     2945 non-null   category
#  18  PROJECT_START_DATE_MONTH   2945 non-null   category
#  19  PROJECT_START_DATE_YEAR    2945 non-null   category
#  20  PROJECT_END_DATE_DAY       2945 non-null   category
#  21  PROJECT_END_DATE_MONTH     2945 non-null   category
#  22  PROJECT_END_DATE_YEAR      2945 non-null   category
#  23  ALLOCATION_START_DAY       2945 non-null   category
#  24  ALLOCATION_START_MONTH     2945 non-null   category
#  25  ALLOCATION_START_YEAR      2945 non-null   category
#  26  ALLOCATION_END_DAY         2945 non-null   category
#  27  ALLOCATION_END_MONTH       2945 non-null   category
#  28  ALLOCATION_END_YEAR        2945 non-null   category
#  29  WEEK_START_DAY             2945 non-null   category
#  30  WEEK_START_MONTH           2945 non-null   category
#  31  WEEK_START_YEAR            2945 non-null   category
#  32  WEEK_END_DAY               2945 non-null   category
#  33  WEEK_END_MONTH             2945 non-null   category
#  34  WEEK_END_YEAR              2945 non-null   category
#  35  project_category           2945 non-null   int32
# dtypes: category(20), float64(10), int32(2), int64(4)
# memory usage: 436.7 KB
# None

# %%
df.columns
# Out:
# Index(['ROLE', 'PROJECT_NAME', 'PROJECT_DURATION', 'PROJECT_CATEGORY',
#        'ALLOCATION_DURATION', 'ACTIVITY', 'MON', 'TUE', 'WED', 'THUR', 'FRI',
#        'SAT', 'SUN', 'TOTAL_WEEK_HOURS', 'HOURS_OVER_OR_UNDER',
#        'ATTENDANCE_REGULARIZATION', 'FEEDBACK_SCORE', 'PROJECT_START_DATE_DAY',
#        'PROJECT_START_DATE_MONTH', 'PROJECT_START_DATE_YEAR',
#        'PROJECT_END_DATE_DAY', 'PROJECT_END_DATE_MONTH',
#        'PROJECT_END_DATE_YEAR', 'ALLOCATION_START_DAY',
#        'ALLOCATION_START_MONTH', 'ALLOCATION_START_YEAR', 'ALLOCATION_END_DAY',
#        'ALLOCATION_END_MONTH', 'ALLOCATION_END_YEAR', 'WEEK_START_DAY',
#        'WEEK_START_MONTH', 'WEEK_START_YEAR', 'WEEK_END_DAY', 'WEEK_END_MONTH',
#        'WEEK_END_YEAR', 'project_category'],
#       dtype='object')

# %%
df['PROJECT_CATEGORY'] = pd.Categorical(df['PROJECT_CATEGORY']).codes
df['ACTIVITY'] = pd.Categorical(df['ACTIVITY']).codes

# %%
print(df)
# Out:
#       ROLE  PROJECT_NAME  PROJECT_DURATION  PROJECT_CATEGORY  \
# 2        2             2                35                 0
# 3        0             0                35                 0
# 4        1             2                35                 0
# 5        3             2                28                 0
# 6        2             2                14                 1
# ...    ...           ...               ...               ...
# 3995     1             2                35                 0
# 3996     0             0                14                 1
# 3997     3             2                42                 0
# 3998     1             2                35                 0
# 3999     3             2                35                 0
#
#       ALLOCATION_DURATION  ACTIVITY  MON   TUE   WED  THUR  ...  \
# 2                      14         2  6.0   6.0   1.0   3.0  ...
# 3                      42         2  2.0   8.0   1.0  11.0  ...
# 4                      28         2  7.0   2.0   8.0   3.0  ...
# 5                      28         1  9.0   5.0   4.0   3.0  ...
# 6                      42         0  9.0   7.0   2.0   4.0  ...
# ...                   ...       ...  ...   ...   ...   ...  ...
# 3995                   28         1  5.0   5.0   3.0  10.0  ...
# 3996                   21         2  3.0   5.0  12.0   2.0  ...
# 3997                   42         0  1.0  11.0   3.0   5.0  ...
# 3998                   28         1  1.0  12.0   6.0   7.0  ...
# 3999                   42         0  4.0   8.0   3.0   5.0  ...
#
#       ALLOCATION_END_DAY  ALLOCATION_END_MONTH  ALLOCATION_END_YEAR  \
# 2                     19                    03                 2024
# 3                     01                    03                 2024
# 4                     06                    11                 2023
# 5                     12                    11                 2023
# 6                     19                    10                 2023
# ...                  ...                   ...                  ...
# 3995                  23                    11                 2023
# 3996                  21                    12                 2023
# 3997                  25                    04                 2024
# 3998                  06                    11                 2023
# 3999                  04                    05                 2024
#
#       WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  \
# 2               2023                12               18          2023
# 3               2024                03               06          2024
# 4               2024                01               11          2024
# 5               2024                02               10          2024
# 6               2023                12               18          2023
# ...              ...               ...              ...           ...
# 3995            2024                01               11          2024
# 3996            2023                05               31          2023
# 3997            2023                10               29          2023
# 3998            2023                12               02          2023
# 3999            2024                01               31          2024
#
#      WEEK_END_MONTH WEEK_END_YEAR project_category
# 2                12            25                0
# 3                03            13                0
# 4                01            18                0
# 5                02            17                0
# 6                12            25                1
# ...             ...           ...              ...
# 3995             01            18                0
# 3996             06            07                1
# 3997             11            05                0
# 3998             12            09                0
# 3999             02            07                0
#
# [2945 rows x 36 columns]

# %%
from scipy.stats import spearmanr

# Compute Spearman correlation coefficients for all features
spearman_corr = df.corr(method='spearman')

# Display the Spearman correlation coefficients
print("Spearman correlation coefficients:")
print(spearman_corr)
# Out:
# Spearman correlation coefficients:
#                                ROLE  PROJECT_NAME  PROJECT_DURATION  \
# ROLE                       1.000000      0.051293          0.072330
# PROJECT_NAME               0.051293      1.000000         -0.075843
# PROJECT_DURATION           0.072330     -0.075843          1.000000
# PROJECT_CATEGORY          -0.068010      0.053981         -0.712665
# ALLOCATION_DURATION        0.197369     -0.022598          0.012835
# ACTIVITY                  -0.007825     -0.119099          0.048836
# MON                       -0.111529     -0.068680         -0.107988
# TUE                        0.109079     -0.108161          0.092237
# WED                       -0.010843      0.043945          0.000849
# THUR                      -0.016656     -0.069084          0.012368
# FRI                        0.103693      0.014041          0.012713
# SAT                       -0.111037     -0.013793         -0.148131
# SUN                       -0.118639     -0.092726         -0.012764
# TOTAL_WEEK_HOURS          -0.052844     -0.091787         -0.049548
# HOURS_OVER_OR_UNDER       -0.052844     -0.091787         -0.049548
# ATTENDANCE_REGULARIZATION  0.053934      0.126295          0.008876
# FEEDBACK_SCORE             0.061008     -0.055841         -0.033535
# PROJECT_START_DATE_DAY    -0.025171      0.197278          0.032130
# PROJECT_START_DATE_MONTH   0.100714     -0.090108          0.011012
# PROJECT_START_DATE_YEAR    0.029224      0.197046         -0.110304
# PROJECT_END_DATE_DAY       0.023020      0.196074          0.109868
# PROJECT_END_DATE_MONTH     0.030495     -0.091170         -0.049915
# PROJECT_END_DATE_YEAR      0.042820      0.012509          0.087550
# ALLOCATION_START_DAY      -0.181965      0.062491          0.103258
# ALLOCATION_START_MONTH    -0.172116      0.022568         -0.179938
# ALLOCATION_START_YEAR      0.317745      0.034996          0.087492
# ALLOCATION_END_DAY        -0.204716      0.061894         -0.228554
# ALLOCATION_END_MONTH      -0.111384     -0.007920         -0.095617
# ALLOCATION_END_YEAR        0.278896      0.054787          0.042350
# WEEK_START_DAY             0.010849     -0.001269         -0.033118
# WEEK_START_MONTH          -0.016399      0.048285         -0.034650
# WEEK_START_YEAR            0.031832      0.067553          0.053531
# WEEK_END_DAY               0.022472     -0.008815         -0.028721
# WEEK_END_MONTH            -0.037640      0.078222         -0.032730
# WEEK_END_YEAR              0.019888     -0.056580         -0.089788
# project_category          -0.068010      0.053981         -0.712665
#
#                            PROJECT_CATEGORY  ALLOCATION_DURATION  ACTIVITY  \
# ROLE                              -0.068010             0.197369 -0.007825
# PROJECT_NAME                       0.053981            -0.022598 -0.119099
# PROJECT_DURATION                  -0.712665             0.012835  0.048836
# PROJECT_CATEGORY                   1.000000            -0.088777 -0.086683
# ALLOCATION_DURATION               -0.088777             1.000000 -0.125865
# ACTIVITY                          -0.086683            -0.125865  1.000000
# MON                                0.121486            -0.082695 -0.162183
# TUE                               -0.060601             0.017772  0.009034
# WED                                0.039107            -0.129228  0.034126
# THUR                              -0.017301            -0.047318 -0.011318
# FRI                               -0.093926            -0.030632 -0.195934
# SAT                                0.131042             0.014824 -0.209656
# SUN                                0.031925            -0.169407  0.009553
# TOTAL_WEEK_HOURS                   0.065816            -0.148545 -0.225093
# HOURS_OVER_OR_UNDER                0.065816            -0.148545 -0.225093
# ATTENDANCE_REGULARIZATION          0.029068             0.139012  0.121318
# FEEDBACK_SCORE                    -0.013577            -0.075875 -0.007240
# PROJECT_START_DATE_DAY            -0.179784            -0.011617 -0.041942
# PROJECT_START_DATE_MONTH           0.105977             0.063316 -0.009038
# PROJECT_START_DATE_YEAR            0.174428             0.029438 -0.117673
# PROJECT_END_DATE_DAY              -0.179943            -0.003254 -0.051357
# PROJECT_END_DATE_MONTH             0.060617             0.051475  0.014643
# PROJECT_END_DATE_YEAR              0.045618             0.045076 -0.122346
# ALLOCATION_START_DAY              -0.033419             0.004647  0.028685
# ALLOCATION_START_MONTH             0.163867            -0.077627 -0.081681
# ALLOCATION_START_YEAR             -0.048810             0.060866  0.014982
# ALLOCATION_END_DAY                 0.291243            -0.103586 -0.063228
# ALLOCATION_END_MONTH               0.050355            -0.055415 -0.049549
# ALLOCATION_END_YEAR                0.010099             0.105153 -0.008274
# WEEK_START_DAY                    -0.069884             0.199004 -0.100223
# WEEK_START_MONTH                   0.171686            -0.116550 -0.096559
# WEEK_START_YEAR                    0.039888            -0.057053 -0.080674
# WEEK_END_DAY                      -0.072274             0.194689 -0.128610
# WEEK_END_MONTH                     0.186504            -0.127899 -0.052513
# WEEK_END_YEAR                      0.035480             0.069686 -0.027813
# project_category                   1.000000            -0.088777 -0.086683
#
#                                 MON       TUE       WED      THUR  ...  \
# ROLE                      -0.111529  0.109079 -0.010843 -0.016656  ...
# PROJECT_NAME              -0.068680 -0.108161  0.043945 -0.069084  ...
# PROJECT_DURATION          -0.107988  0.092237  0.000849  0.012368  ...
# PROJECT_CATEGORY           0.121486 -0.060601  0.039107 -0.017301  ...
# ALLOCATION_DURATION       -0.082695  0.017772 -0.129228 -0.047318  ...
# ACTIVITY                  -0.162183  0.009034  0.034126 -0.011318  ...
# MON                        1.000000 -0.062622  0.070164  0.120848  ...
# TUE                       -0.062622  1.000000 -0.136193  0.192474  ...
# WED                        0.070164 -0.136193  1.000000  0.053475  ...
# THUR                       0.120848  0.192474  0.053475  1.000000  ...
# FRI                       -0.107832 -0.121044  0.095631 -0.004304  ...
# SAT                        0.247728 -0.218041 -0.023496  0.045930  ...
# SUN                        0.156638 -0.069425  0.003279  0.070738  ...
# TOTAL_WEEK_HOURS           0.526591  0.225758  0.341887  0.521427  ...
# HOURS_OVER_OR_UNDER        0.526591  0.225758  0.341887  0.521427  ...
# ATTENDANCE_REGULARIZATION -0.353489 -0.225123 -0.332809 -0.499488  ...
# FEEDBACK_SCORE             0.027696  0.034216 -0.034078  0.018402  ...
# PROJECT_START_DATE_DAY     0.081734 -0.050219  0.013230  0.010962  ...
# PROJECT_START_DATE_MONTH  -0.129918 -0.045495 -0.014076 -0.088071  ...
# PROJECT_START_DATE_YEAR    0.088315  0.026640 -0.107946 -0.002787  ...
# PROJECT_END_DATE_DAY       0.062445 -0.103203  0.051674 -0.038161  ...
# PROJECT_END_DATE_MONTH    -0.113729  0.068172 -0.090127 -0.001770  ...
# PROJECT_END_DATE_YEAR      0.077328 -0.123576  0.010578 -0.057172  ...
# ALLOCATION_START_DAY      -0.076473 -0.053367  0.103672  0.053137  ...
# ALLOCATION_START_MONTH     0.113613 -0.071273 -0.072837 -0.024388  ...
# ALLOCATION_START_YEAR     -0.031349  0.060520  0.033149  0.020593  ...
# ALLOCATION_END_DAY         0.098973 -0.047518 -0.075396 -0.025831  ...
# ALLOCATION_END_MONTH       0.038614 -0.067068 -0.037489 -0.032896  ...
# ALLOCATION_END_YEAR        0.002081  0.054884  0.013630  0.024980  ...
# WEEK_START_DAY             0.039594 -0.168140 -0.077156 -0.213025  ...
# WEEK_START_MONTH           0.095158  0.135971 -0.070497  0.222627  ...
# WEEK_START_YEAR           -0.263377  0.120455  0.074836 -0.153780  ...
# WEEK_END_DAY               0.045794 -0.158573 -0.051805 -0.185432  ...
# WEEK_END_MONTH             0.048103  0.134499 -0.080324  0.184473  ...
# WEEK_END_YEAR              0.191652 -0.123717 -0.226647 -0.160702  ...
# project_category           0.121486 -0.060601  0.039107 -0.017301  ...
#
#                            ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# ROLE                                -0.204716             -0.111384
# PROJECT_NAME                         0.061894             -0.007920
# PROJECT_DURATION                    -0.228554             -0.095617
# PROJECT_CATEGORY                     0.291243              0.050355
# ALLOCATION_DURATION                 -0.103586             -0.055415
# ACTIVITY                            -0.063228             -0.049549
# MON                                  0.098973              0.038614
# TUE                                 -0.047518             -0.067068
# WED                                 -0.075396             -0.037489
# THUR                                -0.025831             -0.032896
# FRI                                  0.087516             -0.025017
# SAT                                  0.048170              0.157486
# SUN                                  0.059972              0.065023
# TOTAL_WEEK_HOURS                     0.077849              0.018758
# HOURS_OVER_OR_UNDER                  0.077849              0.018758
# ATTENDANCE_REGULARIZATION            0.014305              0.001834
# FEEDBACK_SCORE                      -0.012212              0.174531
# PROJECT_START_DATE_DAY              -0.087235              0.031332
# PROJECT_START_DATE_MONTH             0.091894             -0.025055
# PROJECT_START_DATE_YEAR              0.180172              0.085438
# PROJECT_END_DATE_DAY                -0.071799              0.069065
# PROJECT_END_DATE_MONTH               0.059284             -0.089975
# PROJECT_END_DATE_YEAR                0.097965             -0.035598
# ALLOCATION_START_DAY                -0.039005             -0.009228
# ALLOCATION_START_MONTH               0.082332              0.811653
# ALLOCATION_START_YEAR                0.010377             -0.688884
# ALLOCATION_END_DAY                   1.000000             -0.010252
# ALLOCATION_END_MONTH                -0.010252              1.000000
# ALLOCATION_END_YEAR                  0.015685             -0.779461
# WEEK_START_DAY                      -0.020089              0.137423
# WEEK_START_MONTH                     0.119674             -0.089124
# WEEK_START_YEAR                      0.011997             -0.031024
# WEEK_END_DAY                        -0.043745              0.133370
# WEEK_END_MONTH                       0.155726             -0.105552
# WEEK_END_YEAR                        0.006210              0.121744
# project_category                     0.291243              0.050355
#
#                            ALLOCATION_END_YEAR  WEEK_START_DAY  \
# ROLE                                  0.278896        0.010849
# PROJECT_NAME                          0.054787       -0.001269
# PROJECT_DURATION                      0.042350       -0.033118
# PROJECT_CATEGORY                      0.010099       -0.069884
# ALLOCATION_DURATION                   0.105153        0.199004
# ACTIVITY                             -0.008274       -0.100223
# MON                                   0.002081        0.039594
# TUE                                   0.054884       -0.168140
# WED                                   0.013630       -0.077156
# THUR                                  0.024980       -0.213025
# FRI                                   0.104584        0.148142
# SAT                                  -0.132037        0.248169
# SUN                                  -0.036805       -0.040838
# TOTAL_WEEK_HOURS                      0.041943       -0.103797
# HOURS_OVER_OR_UNDER                   0.041943       -0.103797
# ATTENDANCE_REGULARIZATION            -0.009799        0.077229
# FEEDBACK_SCORE                       -0.125939       -0.085455
# PROJECT_START_DATE_DAY               -0.045832        0.034082
# PROJECT_START_DATE_MONTH              0.038666        0.047333
# PROJECT_START_DATE_YEAR              -0.010399        0.070241
# PROJECT_END_DATE_DAY                 -0.062500        0.103340
# PROJECT_END_DATE_MONTH                0.067278       -0.075036
# PROJECT_END_DATE_YEAR                 0.072880        0.089393
# ALLOCATION_START_DAY                 -0.021426       -0.171936
# ALLOCATION_START_MONTH               -0.611681        0.123837
# ALLOCATION_START_YEAR                 0.923446       -0.169980
# ALLOCATION_END_DAY                    0.015685       -0.020089
# ALLOCATION_END_MONTH                 -0.779461        0.137423
# ALLOCATION_END_YEAR                   1.000000       -0.169983
# WEEK_START_DAY                       -0.169983        1.000000
# WEEK_START_MONTH                      0.156280       -0.832303
# WEEK_START_YEAR                       0.071785        0.066552
# WEEK_END_DAY                         -0.173048        0.972525
# WEEK_END_MONTH                        0.184898       -0.804764
# WEEK_END_YEAR                        -0.107988       -0.035852
# project_category                      0.010099       -0.069884
#
#                            WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  \
# ROLE                              -0.016399         0.031832      0.022472
# PROJECT_NAME                       0.048285         0.067553     -0.008815
# PROJECT_DURATION                  -0.034650         0.053531     -0.028721
# PROJECT_CATEGORY                   0.171686         0.039888     -0.072274
# ALLOCATION_DURATION               -0.116550        -0.057053      0.194689
# ACTIVITY                          -0.096559        -0.080674     -0.128610
# MON                                0.095158        -0.263377      0.045794
# TUE                                0.135971         0.120455     -0.158573
# WED                               -0.070497         0.074836     -0.051805
# THUR                               0.222627        -0.153780     -0.185432
# FRI                               -0.136756         0.110921      0.157511
# SAT                               -0.092835        -0.110259      0.241854
# SUN                                0.114368        -0.201688     -0.031837
# TOTAL_WEEK_HOURS                   0.197545        -0.193566     -0.078211
# HOURS_OVER_OR_UNDER                0.197545        -0.193566     -0.078211
# ATTENDANCE_REGULARIZATION         -0.111303         0.230613      0.053472
# FEEDBACK_SCORE                     0.035503        -0.001434     -0.076153
# PROJECT_START_DATE_DAY            -0.034621        -0.069036      0.038951
# PROJECT_START_DATE_MONTH          -0.030415         0.041157      0.037933
# PROJECT_START_DATE_YEAR            0.035496        -0.098003      0.054057
# PROJECT_END_DATE_DAY              -0.101123        -0.049539      0.104364
# PROJECT_END_DATE_MONTH             0.081933         0.015080     -0.078350
# PROJECT_END_DATE_YEAR             -0.002724        -0.042116      0.081824
# ALLOCATION_START_DAY               0.056851         0.158477     -0.168834
# ALLOCATION_START_MONTH            -0.022063        -0.093401      0.115458
# ALLOCATION_START_YEAR              0.126533         0.108622     -0.171288
# ALLOCATION_END_DAY                 0.119674         0.011997     -0.043745
# ALLOCATION_END_MONTH              -0.089124        -0.031024      0.133370
# ALLOCATION_END_YEAR                0.156280         0.071785     -0.173048
# WEEK_START_DAY                    -0.832303         0.066552      0.972525
# WEEK_START_MONTH                   1.000000        -0.196218     -0.784828
# WEEK_START_YEAR                   -0.196218         1.000000      0.093062
# WEEK_END_DAY                      -0.784828         0.093062      1.000000
# WEEK_END_MONTH                     0.926648        -0.119227     -0.839274
# WEEK_END_YEAR                      0.137800        -0.413311     -0.070129
# project_category                   0.171686         0.039888     -0.072274
#
#                            WEEK_END_MONTH  WEEK_END_YEAR  project_category
# ROLE                            -0.037640       0.019888         -0.068010
# PROJECT_NAME                     0.078222      -0.056580          0.053981
# PROJECT_DURATION                -0.032730      -0.089788         -0.712665
# PROJECT_CATEGORY                 0.186504       0.035480          1.000000
# ALLOCATION_DURATION             -0.127899       0.069686         -0.088777
# ACTIVITY                        -0.052513      -0.027813         -0.086683
# MON                              0.048103       0.191652          0.121486
# TUE                              0.134499      -0.123717         -0.060601
# WED                             -0.080324      -0.226647          0.039107
# THUR                             0.184473      -0.160702         -0.017301
# FRI                             -0.149741       0.006056         -0.093926
# SAT                             -0.099295       0.102757          0.131042
# SUN                              0.062957       0.252793          0.031925
# TOTAL_WEEK_HOURS                 0.137123       0.044438          0.065816
# HOURS_OVER_OR_UNDER              0.137123       0.044438          0.065816
# ATTENDANCE_REGULARIZATION       -0.050939      -0.053636          0.029068
# FEEDBACK_SCORE                   0.018484       0.034039         -0.013577
# PROJECT_START_DATE_DAY          -0.048872      -0.035389         -0.179784
# PROJECT_START_DATE_MONTH        -0.015480       0.031766          0.105977
# PROJECT_START_DATE_YEAR          0.039285       0.068170          0.174428
# PROJECT_END_DATE_DAY            -0.108415      -0.021050         -0.179943
# PROJECT_END_DATE_MONTH           0.084519       0.013750          0.060617
# PROJECT_END_DATE_YEAR            0.011971      -0.026357          0.045618
# ALLOCATION_START_DAY             0.087964      -0.134127         -0.033419
# ALLOCATION_START_MONTH          -0.040118       0.182793          0.163867
# ALLOCATION_START_YEAR            0.157670      -0.151576         -0.048810
# ALLOCATION_END_DAY               0.155726       0.006210          0.291243
# ALLOCATION_END_MONTH            -0.105552       0.121744          0.050355
# ALLOCATION_END_YEAR              0.184898      -0.107988          0.010099
# WEEK_START_DAY                  -0.804764      -0.035852         -0.069884
# WEEK_START_MONTH                 0.926648       0.137800          0.171686
# WEEK_START_YEAR                 -0.119227      -0.413311          0.039888
# WEEK_END_DAY                    -0.839274      -0.070129         -0.072274
# WEEK_END_MONTH                   1.000000       0.074909          0.186504
# WEEK_END_YEAR                    0.074909       1.000000          0.035480
# project_category                 0.186504       0.035480          1.000000
#
# [36 rows x 36 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute Spearman correlation coefficients for all features
spearman_corr = df.corr(method='spearman')

# Plot heatmap with larger box sizes
plt.figure(figsize=(8, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=2)
plt.title('Spearman Correlation Coefficients')
plt.show()

# %%
df.to_csv('processed_data.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the distribution of attendance_regularization
plt.figure(figsize=(8, 6))
sns.countplot(x='ATTENDANCE_REGULARIZATION', data=df)
plt.title('Distribution of Attendance Regularization')
plt.xlabel('Attendance Regularization')
plt.ylabel('Count')
plt.show()

# %%
df.columns
# Out:
# Index(['ROLE', 'PROJECT_NAME', 'PROJECT_DURATION', 'PROJECT_CATEGORY',
#        'ALLOCATION_DURATION', 'ACTIVITY', 'MON', 'TUE', 'WED', 'THUR', 'FRI',
#        'SAT', 'SUN', 'TOTAL_WEEK_HOURS', 'HOURS_OVER_OR_UNDER',
#        'ATTENDANCE_REGULARIZATION', 'FEEDBACK_SCORE', 'PROJECT_START_DATE_DAY',
#        'PROJECT_START_DATE_MONTH', 'PROJECT_START_DATE_YEAR',
#        'PROJECT_END_DATE_DAY', 'PROJECT_END_DATE_MONTH',
#        'PROJECT_END_DATE_YEAR', 'ALLOCATION_START_DAY',
#        'ALLOCATION_START_MONTH', 'ALLOCATION_START_YEAR', 'ALLOCATION_END_DAY',
#        'ALLOCATION_END_MONTH', 'ALLOCATION_END_YEAR', 'WEEK_START_DAY',
#        'WEEK_START_MONTH', 'WEEK_START_YEAR', 'WEEK_END_DAY', 'WEEK_END_MONTH',
#        'WEEK_END_YEAR', 'project_category'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.under_sampling import RandomUnderSampler

# Separate the features (X) and the target variable (y)
X = df.drop(columns=['ATTENDANCE_REGULARIZATION'])
y = df['ATTENDANCE_REGULARIZATION']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

undersampler = RandomUnderSampler(random_state=22)
X_balanced, y_balanced = undersampler.fit_resample(X_train, y_train)
svm_classifier = SVC(kernel='rbf', C=0.1, gamma='scale')
svm_classifier.fit(X_balanced, y_balanced)
svm_predictions = svm_classifier.predict(X_test)

svm_accuracy = accuracy_score(y_test, svm_predictions)
svm_classification_report = classification_report(y_test, svm_predictions)
print("SVM Accuracy:", svm_accuracy)
print("SVM Classification Report:\n", svm_classification_report)
# Out:
# SVM Accuracy: 0.8106960950764007
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78       614
#            1       0.72      1.00      0.83       564
#
#     accuracy                           0.81      1178
#    macro avg       0.86      0.82      0.81      1178
# weighted avg       0.86      0.81      0.81      1178

# %%
new_data = pd.read_csv("new_data.csv")
predictions = svm_classifier.predict(new_data)
new_data['attendance_regularization_prediction'] = predictions
print(new_data)
# Out:
#    ROLE  PROJECT_NAME  PROJECT_DURATION  PROJECT_CATEGORY  \
# 0     2             0                21                 0
# 1     2             2                28                 0
#
#    ALLOCATION_DURATION  ACTIVITY  MON  TUE  WED  THUR  ...  \
# 0                   42         0    8    3    5    10  ...
# 1                   21         2   10    1    8     5  ...
#
#    ALLOCATION_END_MONTH  ALLOCATION_END_YEAR  WEEK_START_DAY  \
# 0                     7                 2023            2024
# 1                     3                 2024            2023
#
#    WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  WEEK_END_MONTH  \
# 0                 1               20          2024               1
# 1                 7                4          2023               7
#
#    WEEK_END_YEAR  project_category  attendance_regularization_prediction
# 0             27                 0                                     0
# 1             11                 0                                     1
#
# [2 rows x 36 columns]

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv('src_data.csv')  
feedback_comments = data['FEEDBACK_COMMENTS']
sid = SentimentIntensityAnalyzer()
sentiment_scores = []
for comment in feedback_comments:
    if isinstance(comment, str):
        sentiment_score = sid.polarity_scores(comment)
        sentiment_scores.append(sentiment_score)
    else:
        sentiment_scores.append({'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0})

sentiment_df = pd.DataFrame(sentiment_scores)
sentiment_df['sentiment'] = sentiment_df['compound'].apply(lambda score: 'positive' if score >= 0.05 else ('negative' if score <= -0.05 else 'neutral'))
print("Sentiment Distribution:")
print(sentiment_df['sentiment'].value_counts())

sentiment_df['sentiment'].value_counts().plot(kind='bar', title='Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# Sentiment Distribution:
# sentiment
# neutral     26494
# positive    20090
# negative    12870
# Name: count, dtype: int64

# %%
sid = SentimentIntensityAnalyzer()

input_text = "This week tasks are very interesting."

sentiment_score = sid.polarity_scores(input_text)

if sentiment_score['compound'] >= 0.05:
    sentiment_label = 'positive'
elif sentiment_score['compound'] <= -0.05:
    sentiment_label = 'negative'
else:
    sentiment_label = 'neutral'
print("Sentiment Score:", sentiment_score)
print("Sentiment Label:", sentiment_label)
# Out:
# Sentiment Score: {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'compound': 0.4576}
# Sentiment Label: positive
