# %%
# !pip install --user snowflake-connector-python

# %%
import snowflake.connector
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Establish connection
conn = snowflake.connector.connect(
          user='aadishmn',
            password='Qwert@123',
            account='tz70231.central-india.azure',
            warehouse='COMPUTE_WH',
            database='JMAN',
            schema='JMAN_SCHEMA',
            role='ACCOUNTADMIN'
)

# Create a cursor object
cur = conn.cursor()

# Execute a query to select data from the table
cur.execute(f'SELECT * FROM JMAN.JMAN_SCHEMA_MART.FINAL_TABLE')

# Fetch the results
rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# Convert the result into a pandas DataFrame for easier manipulation
dataset = pd.DataFrame(rows, columns=[x[0] for x in cur.description])

# %%
dataset = pd.DataFrame(rows, columns=[x[0] for x in cur.description])

# %%
dataset.to_csv('src_data.csv', index=False)
df=dataset.copy()

# %%
df
# Out:
#       FIRST_NAME  LAST_NAME                 EMAIL  GENDER DOB_DD_MM_YYYY  \
# 0           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 1           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 2           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 3           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 4           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# ...          ...        ...                   ...     ...            ...
# 59449        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59450        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59451        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59452        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59453        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
#
#       USER_TYPE    ROLE  AGE                       CLIENT_NAME  \
# 0          User  intern   40  VonRueden, Bartell and Halvorson
# 1          User  intern   30                     Crist-Wiegand
# 2          User  intern   30                     Crist-Wiegand
# 3          User  intern   40  VonRueden, Bartell and Halvorson
# 4          User  intern   30  VonRueden, Bartell and Halvorson
# ...         ...     ...  ...                               ...
# 59449      User  intern   25                       Strosin Inc
# 59450      User  intern   25                       Strosin Inc
# 59451      User  intern   29                    Leannon-Grimes
# 59452      User  intern   29                    Leannon-Grimes
# 59453      User  intern   29                       Strosin Inc
#
#               PROJECT_NAME  ... HOURS_OVER_OR_UNDER FEEDBACK_START_PERIOD  \
# 0      Software_Developper  ...                15.0            2024-02-01
# 1      Software_Developper  ...                15.0            2024-02-01
# 2      Software_Developper  ...                15.0            2024-02-01
# 3      Software_Developper  ...                15.0            2024-02-01
# 4      Software_Developper  ...                15.0            2024-02-01
# ...                    ...  ...                 ...                   ...
# 59449           Consulting  ...                -3.0                  None
# 59450           Consulting  ...                -3.0                  None
# 59451  Software_Developper  ...                -3.0                  None
# 59452  Software_Developper  ...                -3.0                  None
# 59453           Consulting  ...                -3.0                  None
#
#        FEEDBACK_END_PERIOD    Q1    Q2    Q3    Q4    Q5    Q6  \
# 0               2024-02-08     3     4     4     1     2     3
# 1               2024-02-08     3     4     4     1     2     3
# 2               2024-02-08     3     4     4     1     2     3
# 3               2024-02-08     3     4     4     1     2     3
# 4               2024-02-08     3     4     4     1     2     3
# ...                    ...   ...   ...   ...   ...   ...   ...
# 59449                 None  None  None  None  None  None  None
# 59450                 None  None  None  None  None  None  None
# 59451                 None  None  None  None  None  None  None
# 59452                 None  None  None  None  None  None  None
# 59453                 None  None  None  None  None  None  None
#
#                                        FEEDBACK_COMMENTS
# 0      Struggling to cope with changing project requi...
# 1      Struggling to cope with changing project requi...
# 2      Struggling to cope with changing project requi...
# 3      Struggling to cope with changing project requi...
# 4      Struggling to cope with changing project requi...
# ...                                                  ...
# 59449                                               None
# 59450                                               None
# 59451                                               None
# 59452                                               None
# 59453                                               None
#
# [59454 rows x 40 columns]

# %%
# Set threshold for total weekly hours
threshold_hours = 35

# Create 'ATTENDANCE_REGULARIZATION' feature based on total weekly hours
df['ATTENDANCE_REGULARIZATION'] = (df['TOTAL_WEEK_HOURS'] > threshold_hours).astype(int)

# %%
df
# Out:
#       FIRST_NAME  LAST_NAME                 EMAIL  GENDER DOB_DD_MM_YYYY  \
# 0           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 1           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 2           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# 3           Alli  Adamowitz  aadamowitz16@hud.gov  Female     10-02-1984
# 4           Alli  Adamowitz  aadamowitz16@hud.gov  Female     02-07-1994
# ...          ...        ...                   ...     ...            ...
# 59449        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59450        Zed    Hardway     zhardwayld@un.org  Female     29-03-1999
# 59451        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59452        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
# 59453        Zed    Hardway     zhardwayld@un.org  Female     15-10-1995
#
#       USER_TYPE    ROLE  AGE                       CLIENT_NAME  \
# 0          User  intern   40  VonRueden, Bartell and Halvorson
# 1          User  intern   30                     Crist-Wiegand
# 2          User  intern   30                     Crist-Wiegand
# 3          User  intern   40  VonRueden, Bartell and Halvorson
# 4          User  intern   30  VonRueden, Bartell and Halvorson
# ...         ...     ...  ...                               ...
# 59449      User  intern   25                       Strosin Inc
# 59450      User  intern   25                       Strosin Inc
# 59451      User  intern   29                    Leannon-Grimes
# 59452      User  intern   29                    Leannon-Grimes
# 59453      User  intern   29                       Strosin Inc
#
#               PROJECT_NAME  ... FEEDBACK_START_PERIOD FEEDBACK_END_PERIOD  \
# 0      Software_Developper  ...            2024-02-01          2024-02-08
# 1      Software_Developper  ...            2024-02-01          2024-02-08
# 2      Software_Developper  ...            2024-02-01          2024-02-08
# 3      Software_Developper  ...            2024-02-01          2024-02-08
# 4      Software_Developper  ...            2024-02-01          2024-02-08
# ...                    ...  ...                   ...                 ...
# 59449           Consulting  ...                  None                None
# 59450           Consulting  ...                  None                None
# 59451  Software_Developper  ...                  None                None
# 59452  Software_Developper  ...                  None                None
# 59453           Consulting  ...                  None                None
#
#          Q1    Q2    Q3    Q4    Q5    Q6  \
# 0         3     4     4     1     2     3
# 1         3     4     4     1     2     3
# 2         3     4     4     1     2     3
# 3         3     4     4     1     2     3
# 4         3     4     4     1     2     3
# ...     ...   ...   ...   ...   ...   ...
# 59449  None  None  None  None  None  None
# 59450  None  None  None  None  None  None
# 59451  None  None  None  None  None  None
# 59452  None  None  None  None  None  None
# 59453  None  None  None  None  None  None
#
#                                        FEEDBACK_COMMENTS  \
# 0      Struggling to cope with changing project requi...
# 1      Struggling to cope with changing project requi...
# 2      Struggling to cope with changing project requi...
# 3      Struggling to cope with changing project requi...
# 4      Struggling to cope with changing project requi...
# ...                                                  ...
# 59449                                               None
# 59450                                               None
# 59451                                               None
# 59452                                               None
# 59453                                               None
#
#       ATTENDANCE_REGULARIZATION
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ...                         ...
# 59449                         1
# 59450                         1
# 59451                         1
# 59452                         1
# 59453                         1
#
# [59454 rows x 41 columns]

# %%
import pandas as pd
import numpy as np

# Read the data

# Ensure 'ATTENDANCE_REGULARIZATION' is numerical
df['ATTENDANCE_REGULARIZATION'] = pd.to_numeric(df['ATTENDANCE_REGULARIZATION'], errors='coerce')

# Sample 500 rows for each value of 'ATTENDANCE_REGULARIZATION'
df_positive = df[df['ATTENDANCE_REGULARIZATION'] == 1].sample(n=2500, random_state=42)
df_negative = df[df['ATTENDANCE_REGULARIZATION'] == 0].sample(n=2500, random_state=42)

# Concatenate the sampled dataframes
df_sampled = pd.concat([df_positive, df_negative])

# Shuffle the DataFrame
df_sampled = df_sampled.sample(frac=1, random_state=42).reset_index(drop=True)

# Display the distribution of 'ATTENDANCE_REGULARIZATION'
print(df_sampled['ATTENDANCE_REGULARIZATION'].value_counts())

# Save the sampled data to a new CSV file
df_sampled.to_csv('new_src_data.csv', index=False)
# Out:
# ATTENDANCE_REGULARIZATION
# 1    2500
# 0    2500
# Name: count, dtype: int64

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
file_path = 'new_src_data.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it was read correctly
print(df.head())
# Out:
#   FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0     Nowell     Carrane           ncarrane7l@twitter.com  Female
# 1   Veronica     Lenihan            vlenihan7b@toplist.cz    Male
# 2      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3      Wendy       Cogle           wcogle8q@google.com.br    Male
# 4     Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
#
#   DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0     27-05-1983      User  software_developper   41
# 1     29-06-2001      User  software_developper   23
# 2     06-03-1984      User           consultant   40
# 3     23-06-1988      User  software_developper   36
# 4     15-01-2002      User  software_developper   22
#
#                     CLIENT_NAME         PROJECT_NAME  ...  \
# 0                   Hintz-Towne           Consulting  ...
# 1                 Hudson-Wisoky  Software_Developper  ...
# 2              Stanton and Sons  Software_Developper  ...
# 3                Feest and Sons  Software_Developper  ...
# 4  Kshlerin, Leffler and Hansen  Software_Developper  ...
#
#   FEEDBACK_START_PERIOD FEEDBACK_END_PERIOD   Q1   Q2   Q3   Q4   Q5   Q6  \
# 0            2023-08-11          2023-08-18  4.0  1.0  3.0  1.0  5.0  1.0
# 1                   NaN                 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2            2023-09-19          2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 3            2023-04-24          2023-05-01  1.0  5.0  4.0  2.0  1.0  1.0
# 4            2023-11-08          2023-11-15  5.0  2.0  3.0  1.0  3.0  1.0
#
#                                    FEEDBACK_COMMENTS ATTENDANCE_REGULARIZATION
# 0            Experiencing burnout due to long hours.                         1
# 1                                                NaN                         0
# 2  Seeking advice on handling difficult conversat...                         0
# 3  Struggling with maintaining team morale during...                         1
# 4  Seeking guidance on managing project budgets a...                         1
#
# [5 rows x 41 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame
# Drop duplicate rows
df = df.drop_duplicates()

# Display the DataFrame without duplicate rows
df
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 1      Veronica     Lenihan            vlenihan7b@toplist.cz    Male
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# ...         ...         ...                              ...     ...
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4978     Jdavie     McCloud            jmccloud5k@joomla.org  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        27-05-1983      User  software_developper   41
# 1        29-06-2001      User  software_developper   23
# 2        06-03-1984      User           consultant   40
# 3        23-06-1988      User  software_developper   36
# 4        15-01-2002      User  software_developper   22
# ...             ...       ...                  ...  ...
# 4975     06-03-1984      User           consultant   40
# 4978     21-03-2001      User  software_developper   23
# 4983     10-10-1984      User           consultant   40
# 4984     14-06-1992      User           consultant   32
# 4999     18-03-1986      User  software_developper   38
#
#                         CLIENT_NAME         PROJECT_NAME  ...  \
# 0                       Hintz-Towne           Consulting  ...
# 1                     Hudson-Wisoky  Software_Developper  ...
# 2                  Stanton and Sons  Software_Developper  ...
# 3                    Feest and Sons  Software_Developper  ...
# 4      Kshlerin, Leffler and Hansen  Software_Developper  ...
# ...                             ...                  ...  ...
# 4975                       West LLC           Consulting  ...
# 4978      Ebert, Padberg and Heller  Software_Developper  ...
# 4983                  Hand-Reichert  Software_Developper  ...
# 4984  Wisozk, Shanahan and Schimmel           Consulting  ...
# 4999   Kshlerin, Leffler and Hansen  Software_Developper  ...
#
#      FEEDBACK_START_PERIOD FEEDBACK_END_PERIOD   Q1   Q2   Q3   Q4   Q5   Q6  \
# 0               2023-08-11          2023-08-18  4.0  1.0  3.0  1.0  5.0  1.0
# 1                      NaN                 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               2023-09-19          2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 3               2023-04-24          2023-05-01  1.0  5.0  4.0  2.0  1.0  1.0
# 4               2023-11-08          2023-11-15  5.0  2.0  3.0  1.0  3.0  1.0
# ...                    ...                 ...  ...  ...  ...  ...  ...  ...
# 4975            2023-09-19          2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 4978            2023-06-14          2023-06-21  4.0  3.0  2.0  4.0  3.0  3.0
# 4983            2023-12-30          2024-01-06  4.0  5.0  4.0  3.0  3.0  3.0
# 4984            2024-02-14          2024-02-21  4.0  5.0  1.0  5.0  4.0  1.0
# 4999            2023-08-21          2023-08-28  4.0  4.0  4.0  4.0  3.0  5.0
#
#                                       FEEDBACK_COMMENTS  \
# 0               Experiencing burnout due to long hours.
# 1                                                   NaN
# 2     Seeking advice on handling difficult conversat...
# 3     Struggling with maintaining team morale during...
# 4     Seeking guidance on managing project budgets a...
# ...                                                 ...
# 4975  Seeking advice on handling difficult conversat...
# 4978  Experiencing challenges in managing project ti...
# 4983  Experiencing difficulties in delegating tasks ...
# 4984  Seeking advice on managing project scope changes.
# 4999  Concerns about the project's ability to delive...
#
#      ATTENDANCE_REGULARIZATION
# 0                            1
# 1                            0
# 2                            0
# 3                            1
# 4                            1
# ...                        ...
# 4975                         1
# 4978                         0
# 4983                         0
# 4984                         0
# 4999                         1
#
# [2699 rows x 41 columns]

# %%
# df.to_csv('src_data.csv', index=False)

# %%
df
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 1      Veronica     Lenihan            vlenihan7b@toplist.cz    Male
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# ...         ...         ...                              ...     ...
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4978     Jdavie     McCloud            jmccloud5k@joomla.org  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        27-05-1983      User  software_developper   41
# 1        29-06-2001      User  software_developper   23
# 2        06-03-1984      User           consultant   40
# 3        23-06-1988      User  software_developper   36
# 4        15-01-2002      User  software_developper   22
# ...             ...       ...                  ...  ...
# 4975     06-03-1984      User           consultant   40
# 4978     21-03-2001      User  software_developper   23
# 4983     10-10-1984      User           consultant   40
# 4984     14-06-1992      User           consultant   32
# 4999     18-03-1986      User  software_developper   38
#
#                         CLIENT_NAME         PROJECT_NAME  ...  \
# 0                       Hintz-Towne           Consulting  ...
# 1                     Hudson-Wisoky  Software_Developper  ...
# 2                  Stanton and Sons  Software_Developper  ...
# 3                    Feest and Sons  Software_Developper  ...
# 4      Kshlerin, Leffler and Hansen  Software_Developper  ...
# ...                             ...                  ...  ...
# 4975                       West LLC           Consulting  ...
# 4978      Ebert, Padberg and Heller  Software_Developper  ...
# 4983                  Hand-Reichert  Software_Developper  ...
# 4984  Wisozk, Shanahan and Schimmel           Consulting  ...
# 4999   Kshlerin, Leffler and Hansen  Software_Developper  ...
#
#      FEEDBACK_START_PERIOD FEEDBACK_END_PERIOD   Q1   Q2   Q3   Q4   Q5   Q6  \
# 0               2023-08-11          2023-08-18  4.0  1.0  3.0  1.0  5.0  1.0
# 1                      NaN                 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               2023-09-19          2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 3               2023-04-24          2023-05-01  1.0  5.0  4.0  2.0  1.0  1.0
# 4               2023-11-08          2023-11-15  5.0  2.0  3.0  1.0  3.0  1.0
# ...                    ...                 ...  ...  ...  ...  ...  ...  ...
# 4975            2023-09-19          2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 4978            2023-06-14          2023-06-21  4.0  3.0  2.0  4.0  3.0  3.0
# 4983            2023-12-30          2024-01-06  4.0  5.0  4.0  3.0  3.0  3.0
# 4984            2024-02-14          2024-02-21  4.0  5.0  1.0  5.0  4.0  1.0
# 4999            2023-08-21          2023-08-28  4.0  4.0  4.0  4.0  3.0  5.0
#
#                                       FEEDBACK_COMMENTS  \
# 0               Experiencing burnout due to long hours.
# 1                                                   NaN
# 2     Seeking advice on handling difficult conversat...
# 3     Struggling with maintaining team morale during...
# 4     Seeking guidance on managing project budgets a...
# ...                                                 ...
# 4975  Seeking advice on handling difficult conversat...
# 4978  Experiencing challenges in managing project ti...
# 4983  Experiencing difficulties in delegating tasks ...
# 4984  Seeking advice on managing project scope changes.
# 4999  Concerns about the project's ability to delive...
#
#      ATTENDANCE_REGULARIZATION
# 0                            1
# 1                            0
# 2                            0
# 3                            1
# 4                            1
# ...                        ...
# 4975                         1
# 4978                         0
# 4983                         0
# 4984                         0
# 4999                         1
#
# [2699 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2699 entries, 0 to 4999
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FIRST_NAME                 2699 non-null   object
#  1   LAST_NAME                  2699 non-null   object
#  2   EMAIL                      2699 non-null   object
#  3   GENDER                     2699 non-null   object
#  4   DOB_DD_MM_YYYY             2699 non-null   object
#  5   USER_TYPE                  2699 non-null   object
#  6   ROLE                       2699 non-null   object
#  7   AGE                        2699 non-null   int64
#  8   CLIENT_NAME                2699 non-null   object
#  9   PROJECT_NAME               2699 non-null   object
#  10  PROJECT_START_DATE         2699 non-null   object
#  11  PROJECT_END_DATE           2699 non-null   object
#  12  PROJECT_DURATION           2699 non-null   int64
#  13  PROJECT_CATEGORY           2699 non-null   object
#  14  ALLOCATION_START           2699 non-null   object
#  15  ALLOCATION_END             2699 non-null   object
#  16  ALLOCATION_DURATION        2699 non-null   int64
#  17  WEEK_START                 2517 non-null   object
#  18  WEEK_END                   2517 non-null   object
#  19  ACTIVITY                   2517 non-null   object
#  20  COMMENTS                   2517 non-null   object
#  21  MON                        2517 non-null   float64
#  22  TUE                        2517 non-null   float64
#  23  WED                        2517 non-null   float64
#  24  THUR                       2517 non-null   float64
#  25  FRI                        2517 non-null   float64
#  26  SAT                        2517 non-null   float64
#  27  SUN                        2517 non-null   float64
#  28  FLAG                       2517 non-null   object
#  29  TOTAL_WEEK_HOURS           2517 non-null   float64
#  30  HOURS_OVER_OR_UNDER        2517 non-null   float64
#  31  FEEDBACK_START_PERIOD      2034 non-null   object
#  32  FEEDBACK_END_PERIOD        2034 non-null   object
#  33  Q1                         2034 non-null   float64
#  34  Q2                         2034 non-null   float64
#  35  Q3                         2034 non-null   float64
#  36  Q4                         2034 non-null   float64
#  37  Q5                         2034 non-null   float64
#  38  Q6                         2034 non-null   float64
#  39  FEEDBACK_COMMENTS          2034 non-null   object
#  40  ATTENDANCE_REGULARIZATION  2699 non-null   int64
# dtypes: float64(15), int64(4), object(22)
# memory usage: 885.6+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Uni-variate Analysis

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['AGE'], bins=10, kde=True)
plt.title('Age Distribution of Users')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot project allocation duration distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['ALLOCATION_DURATION'].dropna(), bins=10, kde=True)
plt.title('Project Allocation Duration Distribution')
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# plt.figure(figsize=(10, 6))
# sns.countplot(x='ROLE', data=df)
# plt.title('Distribution of Roles')
# plt.xlabel('Role')
# plt.ylabel('Count')
# plt.show()

# %%
role_counts = df['ROLE'].value_counts()


plt.figure(figsize=(10, 6))
sns.barplot(x=role_counts.index, y=role_counts.values)
plt.title('Number of Users Submitted based on Role')
plt.xlabel('Role')
plt.ylabel('Number of Users')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate overall feedback score
feedback_columns = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']
df['FEEDBACK_SCORE'] = df[feedback_columns].mean(axis=1)

# Plot a histogram of feedback scores
plt.figure(figsize=(10, 6))
sns.histplot(df['FEEDBACK_SCORE'], bins=10, kde=True)
plt.title('Distribution of Feedback Scores')
plt.xlabel('Feedback Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Bi-variate Analysis

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='PROJECT_CATEGORY', hue='ROLE', data=df)
plt.title('Distribution of Roles by Project Category (Project Allocation Data)')
plt.xlabel('Project Category')
plt.ylabel('Count')
plt.legend(title='Role')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

for i, question in enumerate(feedback_questions):
    sns.histplot(df[question], ax=axes[i//3, i%3])
    axes[i//3, i%3].set_title(f'Distribution of {question}')
    axes[i//3, i%3].set_xlabel('Rating')
    axes[i//3, i%3].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# # Counting the occurrences of each role for each project category
# role_counts = project_allocation_data.groupby(['PROJECT_CATEGORY', 'ROLE']).size().unstack(fill_value=0)

# # Plotting pie charts for each project category
# fig, axes = plt.subplots(nrows=1, ncols=len(role_counts), figsize=(15, 5))
# fig.suptitle('Proportion of Roles by Project Category (Project Allocation Data)')

# for i, (project_category, role_count) in enumerate(role_counts.items()):
#     axes[i].pie(role_count, labels=role_count.index, autopct='%1.1f%%', startangle=90)
#     axes[i].set_title(project_category)

# plt.show()

# %%
df
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 1      Veronica     Lenihan            vlenihan7b@toplist.cz    Male
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# ...         ...         ...                              ...     ...
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4978     Jdavie     McCloud            jmccloud5k@joomla.org  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        27-05-1983      User  software_developper   41
# 1        29-06-2001      User  software_developper   23
# 2        06-03-1984      User           consultant   40
# 3        23-06-1988      User  software_developper   36
# 4        15-01-2002      User  software_developper   22
# ...             ...       ...                  ...  ...
# 4975     06-03-1984      User           consultant   40
# 4978     21-03-2001      User  software_developper   23
# 4983     10-10-1984      User           consultant   40
# 4984     14-06-1992      User           consultant   32
# 4999     18-03-1986      User  software_developper   38
#
#                         CLIENT_NAME         PROJECT_NAME  ...  \
# 0                       Hintz-Towne           Consulting  ...
# 1                     Hudson-Wisoky  Software_Developper  ...
# 2                  Stanton and Sons  Software_Developper  ...
# 3                    Feest and Sons  Software_Developper  ...
# 4      Kshlerin, Leffler and Hansen  Software_Developper  ...
# ...                             ...                  ...  ...
# 4975                       West LLC           Consulting  ...
# 4978      Ebert, Padberg and Heller  Software_Developper  ...
# 4983                  Hand-Reichert  Software_Developper  ...
# 4984  Wisozk, Shanahan and Schimmel           Consulting  ...
# 4999   Kshlerin, Leffler and Hansen  Software_Developper  ...
#
#      FEEDBACK_END_PERIOD   Q1   Q2   Q3   Q4   Q5   Q6  \
# 0             2023-08-18  4.0  1.0  3.0  1.0  5.0  1.0
# 1                    NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2             2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 3             2023-05-01  1.0  5.0  4.0  2.0  1.0  1.0
# 4             2023-11-15  5.0  2.0  3.0  1.0  3.0  1.0
# ...                  ...  ...  ...  ...  ...  ...  ...
# 4975          2023-09-26  1.0  1.0  4.0  2.0  4.0  1.0
# 4978          2023-06-21  4.0  3.0  2.0  4.0  3.0  3.0
# 4983          2024-01-06  4.0  5.0  4.0  3.0  3.0  3.0
# 4984          2024-02-21  4.0  5.0  1.0  5.0  4.0  1.0
# 4999          2023-08-28  4.0  4.0  4.0  4.0  3.0  5.0
#
#                                       FEEDBACK_COMMENTS  \
# 0               Experiencing burnout due to long hours.
# 1                                                   NaN
# 2     Seeking advice on handling difficult conversat...
# 3     Struggling with maintaining team morale during...
# 4     Seeking guidance on managing project budgets a...
# ...                                                 ...
# 4975  Seeking advice on handling difficult conversat...
# 4978  Experiencing challenges in managing project ti...
# 4983  Experiencing difficulties in delegating tasks ...
# 4984  Seeking advice on managing project scope changes.
# 4999  Concerns about the project's ability to delive...
#
#      ATTENDANCE_REGULARIZATION FEEDBACK_SCORE
# 0                            1       2.500000
# 1                            0            NaN
# 2                            0       2.166667
# 3                            1       2.333333
# 4                            1       2.500000
# ...                        ...            ...
# 4975                         1       2.166667
# 4978                         0       3.166667
# 4983                         0       3.666667
# 4984                         0       3.333333
# 4999                         1       4.000000
#
# [2699 rows x 42 columns]

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# feedback_questions = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']
# num_questions = len(feedback_questions)

# fig, axes = plt.subplots(nrows=num_questions, ncols=1, figsize=(10, 5*num_questions))

# for i, question in enumerate(feedback_questions):
#     # Bar plot for feedback ratings by role
#     sns.barplot(x='ROLE', y=question, data=df, ax=axes[i])
#     axes[i].set_title(f'Average Feedback Rating ({question}) by Role')
#     axes[i].set_xlabel('Role')
#     axes[i].set_ylabel(f'Average Rating ({question})')
#     axes[i].tick_params(axis='x', rotation=45)
#     axes[i].set_ylim(0, 5)  # Setting the y-axis limit to 0-5

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Feature Engineering

# %%
# Convert data to DataFrame

# Split date fields into day, month, and year and add them as new columns
date_columns = ["DOB_DD_MM_YYYY", "PROJECT_START_DATE", "PROJECT_END_DATE", "ALLOCATION_START", "ALLOCATION_END", "WEEK_START", "WEEK_END", "FEEDBACK_START_PERIOD", "FEEDBACK_END_PERIOD"]

# Convert date columns to string type
df[date_columns] = df[date_columns].astype(str)

# Split date fields into day, month, and year and add them as new columns
for column in date_columns:
    # Split the date string into day, month, and year components
    split_date = df[column].str.split('-', n=2, expand=True)
    df[column + '_DAY'] = split_date[0]
    df[column + '_MONTH'] = split_date[1]
    df[column + '_YEAR'] = split_date[2]

# Display the updated DataFrame
print(df)
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 1      Veronica     Lenihan            vlenihan7b@toplist.cz    Male
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# ...         ...         ...                              ...     ...
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4978     Jdavie     McCloud            jmccloud5k@joomla.org  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        27-05-1983      User  software_developper   41
# 1        29-06-2001      User  software_developper   23
# 2        06-03-1984      User           consultant   40
# 3        23-06-1988      User  software_developper   36
# 4        15-01-2002      User  software_developper   22
# ...             ...       ...                  ...  ...
# 4975     06-03-1984      User           consultant   40
# 4978     21-03-2001      User  software_developper   23
# 4983     10-10-1984      User           consultant   40
# 4984     14-06-1992      User           consultant   32
# 4999     18-03-1986      User  software_developper   38
#
#                         CLIENT_NAME         PROJECT_NAME  ... WEEK_START_YEAR  \
# 0                       Hintz-Towne           Consulting  ...              20
# 1                     Hudson-Wisoky  Software_Developper  ...              31
# 2                  Stanton and Sons  Software_Developper  ...              29
# 3                    Feest and Sons  Software_Developper  ...              13
# 4      Kshlerin, Leffler and Hansen  Software_Developper  ...              17
# ...                             ...                  ...  ...             ...
# 4975                       West LLC           Consulting  ...              19
# 4978      Ebert, Padberg and Heller  Software_Developper  ...            None
# 4983                  Hand-Reichert  Software_Developper  ...              10
# 4984  Wisozk, Shanahan and Schimmel           Consulting  ...              15
# 4999   Kshlerin, Leffler and Hansen  Software_Developper  ...              11
#
#      WEEK_END_DAY  WEEK_END_MONTH WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0            2024              01            27                      2023
# 1            2024              02            07                       nan
# 2            2023              05            06                      2023
# 3            2023              05            20                      2023
# 4            2023              11            24                      2023
# ...           ...             ...           ...                       ...
# 4975         2023              05            26                      2023
# 4978          nan            None          None                      2023
# 4983         2023              10            17                      2023
# 4984         2023              04            22                      2024
# 4999         2023              10            18                      2023
#
#      FEEDBACK_START_PERIOD_MONTH  FEEDBACK_START_PERIOD_YEAR  \
# 0                             08                          11
# 1                           None                        None
# 2                             09                          19
# 3                             04                          24
# 4                             11                          08
# ...                          ...                         ...
# 4975                          09                          19
# 4978                          06                          14
# 4983                          12                          30
# 4984                          02                          14
# 4999                          08                          21
#
#      FEEDBACK_END_PERIOD_DAY FEEDBACK_END_PERIOD_MONTH  \
# 0                       2023                        08
# 1                        nan                      None
# 2                       2023                        09
# 3                       2023                        05
# 4                       2023                        11
# ...                      ...                       ...
# 4975                    2023                        09
# 4978                    2023                        06
# 4983                    2024                        01
# 4984                    2024                        02
# 4999                    2023                        08
#
#      FEEDBACK_END_PERIOD_YEAR
# 0                          18
# 1                        None
# 2                          26
# 3                          01
# 4                          15
# ...                       ...
# 4975                       26
# 4978                       21
# 4983                       06
# 4984                       21
# 4999                       28
#
# [2699 rows x 69 columns]

# %%
df
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 1      Veronica     Lenihan            vlenihan7b@toplist.cz    Male
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# ...         ...         ...                              ...     ...
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4978     Jdavie     McCloud            jmccloud5k@joomla.org  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        27-05-1983      User  software_developper   41
# 1        29-06-2001      User  software_developper   23
# 2        06-03-1984      User           consultant   40
# 3        23-06-1988      User  software_developper   36
# 4        15-01-2002      User  software_developper   22
# ...             ...       ...                  ...  ...
# 4975     06-03-1984      User           consultant   40
# 4978     21-03-2001      User  software_developper   23
# 4983     10-10-1984      User           consultant   40
# 4984     14-06-1992      User           consultant   32
# 4999     18-03-1986      User  software_developper   38
#
#                         CLIENT_NAME         PROJECT_NAME  ... WEEK_START_YEAR  \
# 0                       Hintz-Towne           Consulting  ...              20
# 1                     Hudson-Wisoky  Software_Developper  ...              31
# 2                  Stanton and Sons  Software_Developper  ...              29
# 3                    Feest and Sons  Software_Developper  ...              13
# 4      Kshlerin, Leffler and Hansen  Software_Developper  ...              17
# ...                             ...                  ...  ...             ...
# 4975                       West LLC           Consulting  ...              19
# 4978      Ebert, Padberg and Heller  Software_Developper  ...            None
# 4983                  Hand-Reichert  Software_Developper  ...              10
# 4984  Wisozk, Shanahan and Schimmel           Consulting  ...              15
# 4999   Kshlerin, Leffler and Hansen  Software_Developper  ...              11
#
#      WEEK_END_DAY  WEEK_END_MONTH WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0            2024              01            27                      2023
# 1            2024              02            07                       nan
# 2            2023              05            06                      2023
# 3            2023              05            20                      2023
# 4            2023              11            24                      2023
# ...           ...             ...           ...                       ...
# 4975         2023              05            26                      2023
# 4978          nan            None          None                      2023
# 4983         2023              10            17                      2023
# 4984         2023              04            22                      2024
# 4999         2023              10            18                      2023
#
#      FEEDBACK_START_PERIOD_MONTH  FEEDBACK_START_PERIOD_YEAR  \
# 0                             08                          11
# 1                           None                        None
# 2                             09                          19
# 3                             04                          24
# 4                             11                          08
# ...                          ...                         ...
# 4975                          09                          19
# 4978                          06                          14
# 4983                          12                          30
# 4984                          02                          14
# 4999                          08                          21
#
#      FEEDBACK_END_PERIOD_DAY FEEDBACK_END_PERIOD_MONTH  \
# 0                       2023                        08
# 1                        nan                      None
# 2                       2023                        09
# 3                       2023                        05
# 4                       2023                        11
# ...                      ...                       ...
# 4975                    2023                        09
# 4978                    2023                        06
# 4983                    2024                        01
# 4984                    2024                        02
# 4999                    2023                        08
#
#      FEEDBACK_END_PERIOD_YEAR
# 0                          18
# 1                        None
# 2                          26
# 3                          01
# 4                          15
# ...                       ...
# 4975                       26
# 4978                       21
# 4983                       06
# 4984                       21
# 4999                       28
#
# [2699 rows x 69 columns]

# %%
# Drop rows with NaN values
df.dropna(inplace=True)

# Display the DataFrame after dropping rows with NaN values
print(df)
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# 5         Briny     Kittman            bkittmannd@dyndns.org    Male
# ...         ...         ...                              ...     ...
# 4973      Briny     Kittman            bkittmannd@dyndns.org    Male
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      DOB_DD_MM_YYYY USER_TYPE                 ROLE  AGE  \
# 0        27-05-1983      User  software_developper   41
# 2        06-03-1984      User           consultant   40
# 3        23-06-1988      User  software_developper   36
# 4        15-01-2002      User  software_developper   22
# 5        04-09-1983      User         tribe_master   41
# ...             ...       ...                  ...  ...
# 4973     04-09-1983      User         tribe_master   41
# 4975     06-03-1984      User           consultant   40
# 4983     10-10-1984      User           consultant   40
# 4984     14-06-1992      User           consultant   32
# 4999     18-03-1986      User  software_developper   38
#
#                         CLIENT_NAME         PROJECT_NAME  ... WEEK_START_YEAR  \
# 0                       Hintz-Towne           Consulting  ...              20
# 2                  Stanton and Sons  Software_Developper  ...              29
# 3                    Feest and Sons  Software_Developper  ...              13
# 4      Kshlerin, Leffler and Hansen  Software_Developper  ...              17
# 5                  Stanton and Sons  Software_Developper  ...              14
# ...                             ...                  ...  ...             ...
# 4973               Stanton and Sons  Software_Developper  ...              14
# 4975                       West LLC           Consulting  ...              19
# 4983                  Hand-Reichert  Software_Developper  ...              10
# 4984  Wisozk, Shanahan and Schimmel           Consulting  ...              15
# 4999   Kshlerin, Leffler and Hansen  Software_Developper  ...              11
#
#      WEEK_END_DAY  WEEK_END_MONTH WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0            2024              01            27                      2023
# 2            2023              05            06                      2023
# 3            2023              05            20                      2023
# 4            2023              11            24                      2023
# 5            2023              09            21                      2023
# ...           ...             ...           ...                       ...
# 4973         2023              05            21                      2023
# 4975         2023              05            26                      2023
# 4983         2023              10            17                      2023
# 4984         2023              04            22                      2024
# 4999         2023              10            18                      2023
#
#      FEEDBACK_START_PERIOD_MONTH  FEEDBACK_START_PERIOD_YEAR  \
# 0                             08                          11
# 2                             09                          19
# 3                             04                          24
# 4                             11                          08
# 5                             06                          18
# ...                          ...                         ...
# 4973                          04                          26
# 4975                          09                          19
# 4983                          12                          30
# 4984                          02                          14
# 4999                          08                          21
#
#      FEEDBACK_END_PERIOD_DAY FEEDBACK_END_PERIOD_MONTH  \
# 0                       2023                        08
# 2                       2023                        09
# 3                       2023                        05
# 4                       2023                        11
# 5                       2023                        06
# ...                      ...                       ...
# 4973                    2023                        05
# 4975                    2023                        09
# 4983                    2024                        01
# 4984                    2024                        02
# 4999                    2023                        08
#
#      FEEDBACK_END_PERIOD_YEAR
# 0                          18
# 2                          26
# 3                          01
# 4                          15
# 5                          25
# ...                       ...
# 4973                       03
# 4975                       26
# 4983                       06
# 4984                       21
# 4999                       28
#
# [1899 rows x 69 columns]

# %%
# Specify the columns to be dropped
columns_to_drop = ['DOB_DD_MM_YYYY', 'ALLOCATION_START', 'ALLOCATION_END', 'FEEDBACK_START_PERIOD', 'FEEDBACK_END_PERIOD']

# Drop the specified columns
df.drop(columns=columns_to_drop, inplace=True)

# Display the DataFrame after dropping the specified columns
df
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# 5         Briny     Kittman            bkittmannd@dyndns.org    Male
# ...         ...         ...                              ...     ...
# 4973      Briny     Kittman            bkittmannd@dyndns.org    Male
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      USER_TYPE                 ROLE  AGE                    CLIENT_NAME  \
# 0         User  software_developper   41                    Hintz-Towne
# 2         User           consultant   40               Stanton and Sons
# 3         User  software_developper   36                 Feest and Sons
# 4         User  software_developper   22   Kshlerin, Leffler and Hansen
# 5         User         tribe_master   41               Stanton and Sons
# ...        ...                  ...  ...                            ...
# 4973      User         tribe_master   41               Stanton and Sons
# 4975      User           consultant   40                       West LLC
# 4983      User           consultant   40                  Hand-Reichert
# 4984      User           consultant   32  Wisozk, Shanahan and Schimmel
# 4999      User  software_developper   38   Kshlerin, Leffler and Hansen
#
#              PROJECT_NAME PROJECT_START_DATE  ... WEEK_START_YEAR  \
# 0              Consulting         2024-01-24  ...              20
# 2     Software_Developper         2024-03-19  ...              29
# 3     Software_Developper         2023-06-13  ...              13
# 4     Software_Developper         2023-06-08  ...              17
# 5     Software_Developper         2024-03-19  ...              14
# ...                   ...                ...  ...             ...
# 4973  Software_Developper         2024-03-19  ...              14
# 4975           Consulting         2023-07-07  ...              19
# 4983  Software_Developper         2023-06-25  ...              10
# 4984           Consulting         2023-09-13  ...              15
# 4999  Software_Developper         2023-06-08  ...              11
#
#       WEEK_END_DAY WEEK_END_MONTH  WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0             2024             01             27                      2023
# 2             2023             05             06                      2023
# 3             2023             05             20                      2023
# 4             2023             11             24                      2023
# 5             2023             09             21                      2023
# ...            ...            ...            ...                       ...
# 4973          2023             05             21                      2023
# 4975          2023             05             26                      2023
# 4983          2023             10             17                      2023
# 4984          2023             04             22                      2024
# 4999          2023             10             18                      2023
#
#      FEEDBACK_START_PERIOD_MONTH FEEDBACK_START_PERIOD_YEAR  \
# 0                             08                         11
# 2                             09                         19
# 3                             04                         24
# 4                             11                         08
# 5                             06                         18
# ...                          ...                        ...
# 4973                          04                         26
# 4975                          09                         19
# 4983                          12                         30
# 4984                          02                         14
# 4999                          08                         21
#
#      FEEDBACK_END_PERIOD_DAY  FEEDBACK_END_PERIOD_MONTH  \
# 0                       2023                         08
# 2                       2023                         09
# 3                       2023                         05
# 4                       2023                         11
# 5                       2023                         06
# ...                      ...                        ...
# 4973                    2023                         05
# 4975                    2023                         09
# 4983                    2024                         01
# 4984                    2024                         02
# 4999                    2023                         08
#
#       FEEDBACK_END_PERIOD_YEAR
# 0                           18
# 2                           26
# 3                           01
# 4                           15
# 5                           25
# ...                        ...
# 4973                        03
# 4975                        26
# 4983                        06
# 4984                        21
# 4999                        28
#
# [1899 rows x 64 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1899 entries, 0 to 4999
# Data columns (total 64 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   FIRST_NAME                   1899 non-null   object
#  1   LAST_NAME                    1899 non-null   object
#  2   EMAIL                        1899 non-null   object
#  3   GENDER                       1899 non-null   object
#  4   USER_TYPE                    1899 non-null   object
#  5   ROLE                         1899 non-null   object
#  6   AGE                          1899 non-null   int64
#  7   CLIENT_NAME                  1899 non-null   object
#  8   PROJECT_NAME                 1899 non-null   object
#  9   PROJECT_START_DATE           1899 non-null   object
#  10  PROJECT_END_DATE             1899 non-null   object
#  11  PROJECT_DURATION             1899 non-null   int64
#  12  PROJECT_CATEGORY             1899 non-null   object
#  13  ALLOCATION_DURATION          1899 non-null   int64
#  14  WEEK_START                   1899 non-null   object
#  15  WEEK_END                     1899 non-null   object
#  16  ACTIVITY                     1899 non-null   object
#  17  COMMENTS                     1899 non-null   object
#  18  MON                          1899 non-null   float64
#  19  TUE                          1899 non-null   float64
#  20  WED                          1899 non-null   float64
#  21  THUR                         1899 non-null   float64
#  22  FRI                          1899 non-null   float64
#  23  SAT                          1899 non-null   float64
#  24  SUN                          1899 non-null   float64
#  25  FLAG                         1899 non-null   object
#  26  TOTAL_WEEK_HOURS             1899 non-null   float64
#  27  HOURS_OVER_OR_UNDER          1899 non-null   float64
#  28  Q1                           1899 non-null   float64
#  29  Q2                           1899 non-null   float64
#  30  Q3                           1899 non-null   float64
#  31  Q4                           1899 non-null   float64
#  32  Q5                           1899 non-null   float64
#  33  Q6                           1899 non-null   float64
#  34  FEEDBACK_COMMENTS            1899 non-null   object
#  35  ATTENDANCE_REGULARIZATION    1899 non-null   int64
#  36  FEEDBACK_SCORE               1899 non-null   float64
#  37  DOB_DD_MM_YYYY_DAY           1899 non-null   object
#  38  DOB_DD_MM_YYYY_MONTH         1899 non-null   object
#  39  DOB_DD_MM_YYYY_YEAR          1899 non-null   object
#  40  PROJECT_START_DATE_DAY       1899 non-null   object
#  41  PROJECT_START_DATE_MONTH     1899 non-null   object
#  42  PROJECT_START_DATE_YEAR      1899 non-null   object
#  43  PROJECT_END_DATE_DAY         1899 non-null   object
#  44  PROJECT_END_DATE_MONTH       1899 non-null   object
#  45  PROJECT_END_DATE_YEAR        1899 non-null   object
#  46  ALLOCATION_START_DAY         1899 non-null   object
#  47  ALLOCATION_START_MONTH       1899 non-null   object
#  48  ALLOCATION_START_YEAR        1899 non-null   object
#  49  ALLOCATION_END_DAY           1899 non-null   object
#  50  ALLOCATION_END_MONTH         1899 non-null   object
#  51  ALLOCATION_END_YEAR          1899 non-null   object
#  52  WEEK_START_DAY               1899 non-null   object
#  53  WEEK_START_MONTH             1899 non-null   object
#  54  WEEK_START_YEAR              1899 non-null   object
#  55  WEEK_END_DAY                 1899 non-null   object
#  56  WEEK_END_MONTH               1899 non-null   object
#  57  WEEK_END_YEAR                1899 non-null   object
#  58  FEEDBACK_START_PERIOD_DAY    1899 non-null   object
#  59  FEEDBACK_START_PERIOD_MONTH  1899 non-null   object
#  60  FEEDBACK_START_PERIOD_YEAR   1899 non-null   object
#  61  FEEDBACK_END_PERIOD_DAY      1899 non-null   object
#  62  FEEDBACK_END_PERIOD_MONTH    1899 non-null   object
#  63  FEEDBACK_END_PERIOD_YEAR     1899 non-null   object
# dtypes: float64(16), int64(4), object(44)
# memory usage: 964.3+ KB

# %%
# # List of columns to be converted to integer type
# columns_to_convert = [
#     'MON', 'TUE', 'WED', 'THUR', 'FRI', 'SAT', 'SUN', 
#     'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 
#     'DOB_DD_MM_YYYY_DAY', 'DOB_DD_MM_YYYY_MONTH', 'DOB_DD_MM_YYYY_YEAR', 
#     'PROJECT_START_DATE_DAY', 'PROJECT_START_DATE_MONTH', 'PROJECT_START_DATE_YEAR', 
#     'PROJECT_END_DATE_DAY', 'PROJECT_END_DATE_MONTH', 'PROJECT_END_DATE_YEAR', 
#     'ALLOCATION_START_DAY', 'ALLOCATION_START_MONTH', 'ALLOCATION_START_YEAR', 
#     'ALLOCATION_END_DAY', 'ALLOCATION_END_MONTH', 'ALLOCATION_END_YEAR', 
#     'WEEK_START_DAY', 'WEEK_START_MONTH', 'WEEK_START_YEAR', 
#     'WEEK_END_DAY', 'WEEK_END_MONTH', 'WEEK_END_YEAR', 
#     'FEEDBACK_START_PERIOD_DAY', 'FEEDBACK_START_PERIOD_MONTH', 'FEEDBACK_START_PERIOD_YEAR', 
#     'FEEDBACK_END_PERIOD_DAY', 'FEEDBACK_END_PERIOD_MONTH', 'FEEDBACK_END_PERIOD_YEAR'
# ]

# # Convert columns to integer type
# df[columns_to_convert] = df[columns_to_convert].astype(int)

# # Display the DataFrame info to confirm the changes
# print(df.info())

# %%
df
# Out:
#      FIRST_NAME   LAST_NAME                            EMAIL  GENDER  \
# 0        Nowell     Carrane           ncarrane7l@twitter.com  Female
# 2         Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 3         Wendy       Cogle           wcogle8q@google.com.br    Male
# 4        Adorne  Bartkowiak  abartkowiakbp@timesonline.co.uk  Female
# 5         Briny     Kittman            bkittmannd@dyndns.org    Male
# ...         ...         ...                              ...     ...
# 4973      Briny     Kittman            bkittmannd@dyndns.org    Male
# 4975      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4983      Chevy  Smitherman   csmitherman19@sciencedaily.com  Female
# 4984       Bing     Nicolls             bnicollsnf@tmall.com    Male
# 4999        Sam    Pfeuffer          spfeufferad@twitpic.com    Male
#
#      USER_TYPE                 ROLE  AGE                    CLIENT_NAME  \
# 0         User  software_developper   41                    Hintz-Towne
# 2         User           consultant   40               Stanton and Sons
# 3         User  software_developper   36                 Feest and Sons
# 4         User  software_developper   22   Kshlerin, Leffler and Hansen
# 5         User         tribe_master   41               Stanton and Sons
# ...        ...                  ...  ...                            ...
# 4973      User         tribe_master   41               Stanton and Sons
# 4975      User           consultant   40                       West LLC
# 4983      User           consultant   40                  Hand-Reichert
# 4984      User           consultant   32  Wisozk, Shanahan and Schimmel
# 4999      User  software_developper   38   Kshlerin, Leffler and Hansen
#
#              PROJECT_NAME PROJECT_START_DATE  ... WEEK_START_YEAR  \
# 0              Consulting         2024-01-24  ...              20
# 2     Software_Developper         2024-03-19  ...              29
# 3     Software_Developper         2023-06-13  ...              13
# 4     Software_Developper         2023-06-08  ...              17
# 5     Software_Developper         2024-03-19  ...              14
# ...                   ...                ...  ...             ...
# 4973  Software_Developper         2024-03-19  ...              14
# 4975           Consulting         2023-07-07  ...              19
# 4983  Software_Developper         2023-06-25  ...              10
# 4984           Consulting         2023-09-13  ...              15
# 4999  Software_Developper         2023-06-08  ...              11
#
#       WEEK_END_DAY WEEK_END_MONTH  WEEK_END_YEAR FEEDBACK_START_PERIOD_DAY  \
# 0             2024             01             27                      2023
# 2             2023             05             06                      2023
# 3             2023             05             20                      2023
# 4             2023             11             24                      2023
# 5             2023             09             21                      2023
# ...            ...            ...            ...                       ...
# 4973          2023             05             21                      2023
# 4975          2023             05             26                      2023
# 4983          2023             10             17                      2023
# 4984          2023             04             22                      2024
# 4999          2023             10             18                      2023
#
#      FEEDBACK_START_PERIOD_MONTH FEEDBACK_START_PERIOD_YEAR  \
# 0                             08                         11
# 2                             09                         19
# 3                             04                         24
# 4                             11                         08
# 5                             06                         18
# ...                          ...                        ...
# 4973                          04                         26
# 4975                          09                         19
# 4983                          12                         30
# 4984                          02                         14
# 4999                          08                         21
#
#      FEEDBACK_END_PERIOD_DAY  FEEDBACK_END_PERIOD_MONTH  \
# 0                       2023                         08
# 2                       2023                         09
# 3                       2023                         05
# 4                       2023                         11
# 5                       2023                         06
# ...                      ...                        ...
# 4973                    2023                         05
# 4975                    2023                         09
# 4983                    2024                         01
# 4984                    2024                         02
# 4999                    2023                         08
#
#       FEEDBACK_END_PERIOD_YEAR
# 0                           18
# 2                           26
# 3                           01
# 4                           15
# 5                           25
# ...                        ...
# 4973                        03
# 4975                        26
# 4983                        06
# 4984                        21
# 4999                        28
#
# [1899 rows x 64 columns]

# %%
# # Drop specified columns
# # columns_to_drop = ['FIRST_NAME','PROJECT_NAME','ALLOCATION_DURATION', 'LAST_NAME', 'CLIENT_NAME', 'PROJECT_START_DATE', 'PROJECT_END_DATE','FEEDBACK_COMMENTS','WEEK_START','WEEK_END','FEEDBACK_START_PERIOD_DAY','FEEDBACK_START_PERIOD_MONTH','FEEDBACK_START_PERIOD_YEAR','FEEDBACK_END_PERIOD_DAY','FEEDBACK_END_PERIOD_MONTH','FEEDBACK_END_PERIOD_YEAR']
columns_to_drop = ['FIRST_NAME', 'LAST_NAME','GENDER','FLAG','EMAIL','USER_TYPE','COMMENTS','AGE','DOB_DD_MM_YYYY_MONTH','DOB_DD_MM_YYYY_YEAR','DOB_DD_MM_YYYY_DAY', 'CLIENT_NAME', 'PROJECT_START_DATE', 'PROJECT_END_DATE','FEEDBACK_COMMENTS','WEEK_START','WEEK_END','FEEDBACK_START_PERIOD_DAY','FEEDBACK_START_PERIOD_MONTH','FEEDBACK_START_PERIOD_YEAR','FEEDBACK_END_PERIOD_DAY','FEEDBACK_END_PERIOD_MONTH','FEEDBACK_END_PERIOD_YEAR','Q1','Q2','Q3','Q4','Q5','Q6']

df = df.drop(columns=columns_to_drop)

# Display the DataFrame after dropping columns
df.head()
# Out:
#                   ROLE         PROJECT_NAME  PROJECT_DURATION  \
# 0  software_developper           Consulting                21
# 2           consultant  Software_Developper                35
# 3  software_developper  Software_Developper                21
# 4  software_developper  Software_Developper                35
# 5         tribe_master  Software_Developper                35
#
#   PROJECT_CATEGORY  ALLOCATION_DURATION        ACTIVITY  MON   TUE  WED  THUR  \
# 0  Mid Cap Project                   42             bau  8.0   3.0  5.0  10.0
# 2  Mid Cap Project                   21  sales_activity  1.0  11.0  4.0   5.0
# 3  Mid Cap Project                   28  sales_activity  8.0  10.0  3.0   9.0
# 4  Mid Cap Project                   42  client_project  6.0  11.0  5.0  11.0
# 5  Mid Cap Project                   42             bau  9.0  12.0  6.0   9.0
#
#    ...  ALLOCATION_START_YEAR  ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# 0  ...                   2023                  13                    07
# 2  ...                   2023                  17                    07
# 3  ...                   2023                  14                    08
# 4  ...                   2023                  09                    10
# 5  ...                   2024                  04                    05
#
#    ALLOCATION_END_YEAR  WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  \
# 0                 2023            2024                01               20
# 2                 2023            2023                04               29
# 3                 2023            2023                05               13
# 4                 2023            2023                11               17
# 5                 2024            2023                09               14
#
#   WEEK_END_DAY WEEK_END_MONTH WEEK_END_YEAR
# 0         2024             01            27
# 2         2023             05            06
# 3         2023             05            20
# 4         2023             11            24
# 5         2023             09            21
#
# [5 rows x 35 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Convert 'GENDER', 'USER_TYPE', and 'ROLE' to numeric values
# df['GENDER'] = label_encoder.fit_transform(df['GENDER'])
# df['USER_TYPE'] = label_encoder.fit_transform(df['USER_TYPE'])
df['ROLE'] = label_encoder.fit_transform(df['ROLE'])
df['PROJECT_NAME'] = label_encoder.fit_transform(df['PROJECT_NAME'])

# Display the DataFrame after conversion
df.head()
# Out:
#    ROLE  PROJECT_NAME  PROJECT_DURATION PROJECT_CATEGORY  ALLOCATION_DURATION  \
# 0     2             0                21  Mid Cap Project                   42
# 2     0             2                35  Mid Cap Project                   21
# 3     2             2                21  Mid Cap Project                   28
# 4     2             2                35  Mid Cap Project                   42
# 5     3             2                35  Mid Cap Project                   42
#
#          ACTIVITY  MON   TUE  WED  THUR  ...  ALLOCATION_START_YEAR  \
# 0             bau  8.0   3.0  5.0  10.0  ...                   2023
# 2  sales_activity  1.0  11.0  4.0   5.0  ...                   2023
# 3  sales_activity  8.0  10.0  3.0   9.0  ...                   2023
# 4  client_project  6.0  11.0  5.0  11.0  ...                   2023
# 5             bau  9.0  12.0  6.0   9.0  ...                   2024
#
#    ALLOCATION_END_DAY  ALLOCATION_END_MONTH  ALLOCATION_END_YEAR  \
# 0                  13                    07                 2023
# 2                  17                    07                 2023
# 3                  14                    08                 2023
# 4                  09                    10                 2023
# 5                  04                    05                 2024
#
#    WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR WEEK_END_DAY  \
# 0            2024                01               20         2024
# 2            2023                04               29         2023
# 3            2023                05               13         2023
# 4            2023                11               17         2023
# 5            2023                09               14         2023
#
#   WEEK_END_MONTH WEEK_END_YEAR
# 0             01            27
# 2             05            06
# 3             05            20
# 4             11            24
# 5             09            21
#
# [5 rows x 35 columns]

# %%
df
# Out:
#       ROLE  PROJECT_NAME  PROJECT_DURATION PROJECT_CATEGORY  \
# 0        2             0                21  Mid Cap Project
# 2        0             2                35  Mid Cap Project
# 3        2             2                21  Mid Cap Project
# 4        2             2                35  Mid Cap Project
# 5        3             2                35  Mid Cap Project
# ...    ...           ...               ...              ...
# 4973     3             2                35  Mid Cap Project
# 4975     0             0                28  Mid Cap Project
# 4983     0             2                21  Mid Cap Project
# 4984     0             0                35  Mid Cap Project
# 4999     2             2                35  Mid Cap Project
#
#       ALLOCATION_DURATION        ACTIVITY  MON   TUE   WED  THUR  ...  \
# 0                      42             bau  8.0   3.0   5.0  10.0  ...
# 2                      21  sales_activity  1.0  11.0   4.0   5.0  ...
# 3                      28  sales_activity  8.0  10.0   3.0   9.0  ...
# 4                      42  client_project  6.0  11.0   5.0  11.0  ...
# 5                      42             bau  9.0  12.0   6.0   9.0  ...
# ...                   ...             ...  ...   ...   ...   ...  ...
# 4973                   42  sales_activity  6.0   8.0  10.0   3.0  ...
# 4975                   21  client_project  5.0   9.0   6.0   8.0  ...
# 4983                   35  client_project  2.0   2.0   3.0  10.0  ...
# 4984                   35  client_project  5.0   4.0  10.0   3.0  ...
# 4999                   28             bau  1.0   3.0  10.0   3.0  ...
#
#       ALLOCATION_START_YEAR  ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# 0                      2023                  13                    07
# 2                      2023                  17                    07
# 3                      2023                  14                    08
# 4                      2023                  09                    10
# 5                      2024                  04                    05
# ...                     ...                 ...                   ...
# 4973                   2024                  04                    05
# 4975                   2023                  17                    07
# 4983                   2023                  01                    07
# 4984                   2023                  05                    08
# 4999                   2023                  10                    08
#
#       ALLOCATION_END_YEAR  WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  \
# 0                    2023            2024                01               20
# 2                    2023            2023                04               29
# 3                    2023            2023                05               13
# 4                    2023            2023                11               17
# 5                    2024            2023                09               14
# ...                   ...             ...               ...              ...
# 4973                 2024            2023                05               14
# 4975                 2023            2023                05               19
# 4983                 2023            2023                10               10
# 4984                 2023            2023                04               15
# 4999                 2023            2023                10               11
#
#      WEEK_END_DAY WEEK_END_MONTH WEEK_END_YEAR
# 0            2024             01            27
# 2            2023             05            06
# 3            2023             05            20
# 4            2023             11            24
# 5            2023             09            21
# ...           ...            ...           ...
# 4973         2023             05            21
# 4975         2023             05            26
# 4983         2023             10            17
# 4984         2023             04            22
# 4999         2023             10            18
#
# [1899 rows x 35 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Convert project_name and project_category to numerical values
# df['project_name'] = label_encoder.fit_transform(df['PROJECT_NAME'])
df['project_category'] = label_encoder.fit_transform(df['PROJECT_CATEGORY'])

# Show the updated DataFrame
print(df)
# Out:
#       ROLE  PROJECT_NAME  PROJECT_DURATION PROJECT_CATEGORY  \
# 0        2             0                21  Mid Cap Project
# 2        0             2                35  Mid Cap Project
# 3        2             2                21  Mid Cap Project
# 4        2             2                35  Mid Cap Project
# 5        3             2                35  Mid Cap Project
# ...    ...           ...               ...              ...
# 4973     3             2                35  Mid Cap Project
# 4975     0             0                28  Mid Cap Project
# 4983     0             2                21  Mid Cap Project
# 4984     0             0                35  Mid Cap Project
# 4999     2             2                35  Mid Cap Project
#
#       ALLOCATION_DURATION        ACTIVITY  MON   TUE   WED  THUR  ...  \
# 0                      42             bau  8.0   3.0   5.0  10.0  ...
# 2                      21  sales_activity  1.0  11.0   4.0   5.0  ...
# 3                      28  sales_activity  8.0  10.0   3.0   9.0  ...
# 4                      42  client_project  6.0  11.0   5.0  11.0  ...
# 5                      42             bau  9.0  12.0   6.0   9.0  ...
# ...                   ...             ...  ...   ...   ...   ...  ...
# 4973                   42  sales_activity  6.0   8.0  10.0   3.0  ...
# 4975                   21  client_project  5.0   9.0   6.0   8.0  ...
# 4983                   35  client_project  2.0   2.0   3.0  10.0  ...
# 4984                   35  client_project  5.0   4.0  10.0   3.0  ...
# 4999                   28             bau  1.0   3.0  10.0   3.0  ...
#
#       ALLOCATION_END_DAY  ALLOCATION_END_MONTH  ALLOCATION_END_YEAR  \
# 0                     13                    07                 2023
# 2                     17                    07                 2023
# 3                     14                    08                 2023
# 4                     09                    10                 2023
# 5                     04                    05                 2024
# ...                  ...                   ...                  ...
# 4973                  04                    05                 2024
# 4975                  17                    07                 2023
# 4983                  01                    07                 2023
# 4984                  05                    08                 2023
# 4999                  10                    08                 2023
#
#       WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  \
# 0               2024                01               20          2024
# 2               2023                04               29          2023
# 3               2023                05               13          2023
# 4               2023                11               17          2023
# 5               2023                09               14          2023
# ...              ...               ...              ...           ...
# 4973            2023                05               14          2023
# 4975            2023                05               19          2023
# 4983            2023                10               10          2023
# 4984            2023                04               15          2023
# 4999            2023                10               11          2023
#
#      WEEK_END_MONTH WEEK_END_YEAR project_category
# 0                01            27                0
# 2                05            06                0
# 3                05            20                0
# 4                11            24                0
# 5                09            21                0
# ...             ...           ...              ...
# 4973             05            21                0
# 4975             05            26                0
# 4983             10            17                0
# 4984             04            22                0
# 4999             10            18                0
#
# [1899 rows x 36 columns]

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Compute the Spearman correlation matrix
# spearman_corr = df.corr(method='spearman')

# # Set up the matplotlib figure
# plt.figure(figsize=(20, 15))

# # Draw the heatmap with the mask and correct aspect ratio
# sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt=".2f", center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# # Rotate x-axis labels for better readability
# plt.xticks(rotation=45)

# # Show plot
# plt.show()

# %%
string_cols = df.select_dtypes(include=['object']).columns
df[string_cols] = df[string_cols].astype('category')

# Convert other data types to numerical
# df['GENDER'] = df['GENDER'].astype('int64')
# df['USER_TYPE'] = df['USER_TYPE'].astype('int64')
df['ROLE'] = df['ROLE'].astype('int64')
# df['PROJECT_NAME'] = df['PROJECT_NAME'].astype('category')
df['PROJECT_CATEGORY'] = df['PROJECT_CATEGORY'].astype('category')

# Display the updated DataFrame info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1899 entries, 0 to 4999
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ROLE                       1899 non-null   int64
#  1   PROJECT_NAME               1899 non-null   int32
#  2   PROJECT_DURATION           1899 non-null   int64
#  3   PROJECT_CATEGORY           1899 non-null   category
#  4   ALLOCATION_DURATION        1899 non-null   int64
#  5   ACTIVITY                   1899 non-null   category
#  6   MON                        1899 non-null   float64
#  7   TUE                        1899 non-null   float64
#  8   WED                        1899 non-null   float64
#  9   THUR                       1899 non-null   float64
#  10  FRI                        1899 non-null   float64
#  11  SAT                        1899 non-null   float64
#  12  SUN                        1899 non-null   float64
#  13  TOTAL_WEEK_HOURS           1899 non-null   float64
#  14  HOURS_OVER_OR_UNDER        1899 non-null   float64
#  15  ATTENDANCE_REGULARIZATION  1899 non-null   int64
#  16  FEEDBACK_SCORE             1899 non-null   float64
#  17  PROJECT_START_DATE_DAY     1899 non-null   category
#  18  PROJECT_START_DATE_MONTH   1899 non-null   category
#  19  PROJECT_START_DATE_YEAR    1899 non-null   category
#  20  PROJECT_END_DATE_DAY       1899 non-null   category
#  21  PROJECT_END_DATE_MONTH     1899 non-null   category
#  22  PROJECT_END_DATE_YEAR      1899 non-null   category
#  23  ALLOCATION_START_DAY       1899 non-null   category
#  24  ALLOCATION_START_MONTH     1899 non-null   category
#  25  ALLOCATION_START_YEAR      1899 non-null   category
#  26  ALLOCATION_END_DAY         1899 non-null   category
#  27  ALLOCATION_END_MONTH       1899 non-null   category
#  28  ALLOCATION_END_YEAR        1899 non-null   category
#  29  WEEK_START_DAY             1899 non-null   category
#  30  WEEK_START_MONTH           1899 non-null   category
#  31  WEEK_START_YEAR            1899 non-null   category
#  32  WEEK_END_DAY               1899 non-null   category
#  33  WEEK_END_MONTH             1899 non-null   category
#  34  WEEK_END_YEAR              1899 non-null   category
#  35  project_category           1899 non-null   int32
# dtypes: category(20), float64(10), int32(2), int64(4)
# memory usage: 285.5 KB
# None

# %%
df.columns
# Out:
# Index(['ROLE', 'PROJECT_NAME', 'PROJECT_DURATION', 'PROJECT_CATEGORY',
#        'ALLOCATION_DURATION', 'ACTIVITY', 'MON', 'TUE', 'WED', 'THUR', 'FRI',
#        'SAT', 'SUN', 'TOTAL_WEEK_HOURS', 'HOURS_OVER_OR_UNDER',
#        'ATTENDANCE_REGULARIZATION', 'FEEDBACK_SCORE', 'PROJECT_START_DATE_DAY',
#        'PROJECT_START_DATE_MONTH', 'PROJECT_START_DATE_YEAR',
#        'PROJECT_END_DATE_DAY', 'PROJECT_END_DATE_MONTH',
#        'PROJECT_END_DATE_YEAR', 'ALLOCATION_START_DAY',
#        'ALLOCATION_START_MONTH', 'ALLOCATION_START_YEAR', 'ALLOCATION_END_DAY',
#        'ALLOCATION_END_MONTH', 'ALLOCATION_END_YEAR', 'WEEK_START_DAY',
#        'WEEK_START_MONTH', 'WEEK_START_YEAR', 'WEEK_END_DAY', 'WEEK_END_MONTH',
#        'WEEK_END_YEAR', 'project_category'],
#       dtype='object')

# %%
# Convert project_name and project_category to numerical data types
# df['PROJECT_NAME'] = pd.Categorical(df['PROJECT_NAME']).codes
df['PROJECT_CATEGORY'] = pd.Categorical(df['PROJECT_CATEGORY']).codes
df['ACTIVITY'] = pd.Categorical(df['ACTIVITY']).codes

# # Extracting domain from email addresses
# df['EMAIL_DOMAIN'] = df['EMAIL'].str.split('@').str[1]

# # Converting domain to numerical using categorical codes
# df['EMAIL_DOMAIN'] = pd.Categorical(df['EMAIL_DOMAIN']).codes

# df=df.drop(columns=['EMAIL'], inplace=True)

# %%
print(df)
# Out:
#       ROLE  PROJECT_NAME  PROJECT_DURATION  PROJECT_CATEGORY  \
# 0        2             0                21                 0
# 2        0             2                35                 0
# 3        2             2                21                 0
# 4        2             2                35                 0
# 5        3             2                35                 0
# ...    ...           ...               ...               ...
# 4973     3             2                35                 0
# 4975     0             0                28                 0
# 4983     0             2                21                 0
# 4984     0             0                35                 0
# 4999     2             2                35                 0
#
#       ALLOCATION_DURATION  ACTIVITY  MON   TUE   WED  THUR  ...  \
# 0                      42         0  8.0   3.0   5.0  10.0  ...
# 2                      21         2  1.0  11.0   4.0   5.0  ...
# 3                      28         2  8.0  10.0   3.0   9.0  ...
# 4                      42         1  6.0  11.0   5.0  11.0  ...
# 5                      42         0  9.0  12.0   6.0   9.0  ...
# ...                   ...       ...  ...   ...   ...   ...  ...
# 4973                   42         2  6.0   8.0  10.0   3.0  ...
# 4975                   21         1  5.0   9.0   6.0   8.0  ...
# 4983                   35         1  2.0   2.0   3.0  10.0  ...
# 4984                   35         1  5.0   4.0  10.0   3.0  ...
# 4999                   28         0  1.0   3.0  10.0   3.0  ...
#
#       ALLOCATION_END_DAY  ALLOCATION_END_MONTH  ALLOCATION_END_YEAR  \
# 0                     13                    07                 2023
# 2                     17                    07                 2023
# 3                     14                    08                 2023
# 4                     09                    10                 2023
# 5                     04                    05                 2024
# ...                  ...                   ...                  ...
# 4973                  04                    05                 2024
# 4975                  17                    07                 2023
# 4983                  01                    07                 2023
# 4984                  05                    08                 2023
# 4999                  10                    08                 2023
#
#       WEEK_START_DAY  WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  \
# 0               2024                01               20          2024
# 2               2023                04               29          2023
# 3               2023                05               13          2023
# 4               2023                11               17          2023
# 5               2023                09               14          2023
# ...              ...               ...              ...           ...
# 4973            2023                05               14          2023
# 4975            2023                05               19          2023
# 4983            2023                10               10          2023
# 4984            2023                04               15          2023
# 4999            2023                10               11          2023
#
#      WEEK_END_MONTH WEEK_END_YEAR project_category
# 0                01            27                0
# 2                05            06                0
# 3                05            20                0
# 4                11            24                0
# 5                09            21                0
# ...             ...           ...              ...
# 4973             05            21                0
# 4975             05            26                0
# 4983             10            17                0
# 4984             04            22                0
# 4999             10            18                0
#
# [1899 rows x 36 columns]

# %%
import pandas as pd
from scipy.stats import spearmanr

# Assuming df contains your DataFrame

# Compute Spearman correlation coefficients for all features
spearman_corr = df.corr(method='spearman')

# Display the Spearman correlation coefficients
print("Spearman correlation coefficients:")
print(spearman_corr)
# Out:
# Spearman correlation coefficients:
#                                ROLE  PROJECT_NAME  PROJECT_DURATION  \
# ROLE                       1.000000      0.005991          0.031673
# PROJECT_NAME               0.005991      1.000000         -0.096014
# PROJECT_DURATION           0.031673     -0.096014          1.000000
# PROJECT_CATEGORY          -0.019503      0.053309         -0.692614
# ALLOCATION_DURATION        0.191754     -0.024502          0.068679
# ACTIVITY                   0.072289     -0.073445          0.014739
# MON                       -0.037438      0.001270         -0.048932
# TUE                        0.057700     -0.065988          0.031200
# WED                        0.018967      0.072156          0.005809
# THUR                       0.013021     -0.051259          0.011304
# FRI                        0.001331      0.004384         -0.048653
# SAT                       -0.064793      0.005482         -0.106358
# SUN                       -0.086153     -0.048451         -0.018385
# TOTAL_WEEK_HOURS          -0.033639     -0.034261         -0.070220
# HOURS_OVER_OR_UNDER       -0.033639     -0.034261         -0.070220
# ATTENDANCE_REGULARIZATION -0.014477     -0.044364         -0.046253
# FEEDBACK_SCORE             0.028550     -0.017356         -0.051387
# PROJECT_START_DATE_DAY    -0.014557      0.221096          0.005455
# PROJECT_START_DATE_MONTH   0.075535     -0.066708         -0.011129
# PROJECT_START_DATE_YEAR   -0.037989      0.184683         -0.094568
# PROJECT_END_DATE_DAY       0.040952      0.253023          0.050197
# PROJECT_END_DATE_MONTH    -0.014256     -0.126029         -0.015878
# PROJECT_END_DATE_YEAR     -0.001514     -0.015362          0.045586
# ALLOCATION_START_DAY      -0.138404      0.067949          0.093030
# ALLOCATION_START_MONTH    -0.143446      0.023560         -0.130386
# ALLOCATION_START_YEAR      0.288381     -0.000307          0.045050
# ALLOCATION_END_DAY        -0.222022      0.064860         -0.223823
# ALLOCATION_END_MONTH      -0.136868     -0.002858         -0.059842
# ALLOCATION_END_YEAR        0.287346      0.016884          0.013697
# WEEK_START_DAY            -0.089772     -0.025002         -0.025772
# WEEK_START_MONTH           0.073192      0.038543         -0.004831
# WEEK_START_YEAR           -0.054631     -0.020525         -0.017720
# WEEK_END_DAY              -0.072655     -0.041122         -0.020175
# WEEK_END_MONTH             0.037653      0.065240         -0.015632
# WEEK_END_YEAR              0.078203      0.002844          0.022930
# project_category          -0.019503      0.053309         -0.692614
#
#                            PROJECT_CATEGORY  ALLOCATION_DURATION  ACTIVITY  \
# ROLE                              -0.019503             0.191754  0.072289
# PROJECT_NAME                       0.053309            -0.024502 -0.073445
# PROJECT_DURATION                  -0.692614             0.068679  0.014739
# PROJECT_CATEGORY                   1.000000            -0.129180 -0.017304
# ALLOCATION_DURATION               -0.129180             1.000000  0.031693
# ACTIVITY                          -0.017304             0.031693  1.000000
# MON                                0.066475            -0.051277 -0.099237
# TUE                               -0.031875             0.012078 -0.057746
# WED                                0.038098            -0.042161 -0.031779
# THUR                              -0.020931             0.004145  0.001119
# FRI                                0.023800            -0.047104 -0.160318
# SAT                                0.086765            -0.004542 -0.043097
# SUN                                0.008513            -0.077415  0.062260
# TOTAL_WEEK_HOURS                   0.072000            -0.079710 -0.118994
# HOURS_OVER_OR_UNDER                0.072000            -0.079710 -0.118994
# ATTENDANCE_REGULARIZATION          0.022617            -0.053376 -0.053429
# FEEDBACK_SCORE                    -0.008112            -0.146051 -0.027032
# PROJECT_START_DATE_DAY            -0.075961            -0.018054  0.002522
# PROJECT_START_DATE_MONTH           0.082260             0.028952 -0.007866
# PROJECT_START_DATE_YEAR            0.149026            -0.026104 -0.013845
# PROJECT_END_DATE_DAY              -0.056136            -0.015548  0.007231
# PROJECT_END_DATE_MONTH            -0.006047             0.029784 -0.010745
# PROJECT_END_DATE_YEAR              0.086934             0.021119 -0.064077
# ALLOCATION_START_DAY              -0.035193             0.046349 -0.040281
# ALLOCATION_START_MONTH             0.118247            -0.142236 -0.029393
# ALLOCATION_START_YEAR             -0.024586             0.150691  0.020851
# ALLOCATION_END_DAY                 0.289585            -0.154869 -0.039619
# ALLOCATION_END_MONTH               0.028571            -0.134808 -0.024237
# ALLOCATION_END_YEAR                0.015638             0.202407  0.017350
# WEEK_START_DAY                    -0.017704             0.113473  0.030031
# WEEK_START_MONTH                   0.068611            -0.069297 -0.137921
# WEEK_START_YEAR                    0.051665            -0.114927 -0.120711
# WEEK_END_DAY                      -0.027019             0.107676 -0.017571
# WEEK_END_MONTH                     0.093880            -0.083715 -0.069390
# WEEK_END_YEAR                     -0.058345             0.090326 -0.002848
# project_category                   1.000000            -0.129180 -0.017304
#
#                                 MON       TUE       WED      THUR  ...  \
# ROLE                      -0.037438  0.057700  0.018967  0.013021  ...
# PROJECT_NAME               0.001270 -0.065988  0.072156 -0.051259  ...
# PROJECT_DURATION          -0.048932  0.031200  0.005809  0.011304  ...
# PROJECT_CATEGORY           0.066475 -0.031875  0.038098 -0.020931  ...
# ALLOCATION_DURATION       -0.051277  0.012078 -0.042161  0.004145  ...
# ACTIVITY                  -0.099237 -0.057746 -0.031779  0.001119  ...
# MON                        1.000000  0.047140  0.062699  0.085976  ...
# TUE                        0.047140  1.000000 -0.096495  0.089448  ...
# WED                        0.062699 -0.096495  1.000000 -0.042872  ...
# THUR                       0.085976  0.089448 -0.042872  1.000000  ...
# FRI                       -0.008057 -0.087124  0.059026 -0.055165  ...
# SAT                        0.055634 -0.175519 -0.029304  0.047218  ...
# SUN                        0.067608  0.013576  0.050197 -0.067726  ...
# TOTAL_WEEK_HOURS           0.500711  0.339223  0.343773  0.408011  ...
# HOURS_OVER_OR_UNDER        0.500711  0.339223  0.343773  0.408011  ...
# ATTENDANCE_REGULARIZATION  0.293696  0.224320  0.281504  0.395419  ...
# FEEDBACK_SCORE             0.011163  0.021696 -0.047189 -0.004726  ...
# PROJECT_START_DATE_DAY     0.050888 -0.046092 -0.040459 -0.014086  ...
# PROJECT_START_DATE_MONTH  -0.085504 -0.021192  0.053769 -0.027168  ...
# PROJECT_START_DATE_YEAR    0.030246 -0.057515 -0.031267 -0.010937  ...
# PROJECT_END_DATE_DAY       0.035806 -0.061693  0.012138 -0.026496  ...
# PROJECT_END_DATE_MONTH    -0.073494  0.012292 -0.035851 -0.003334  ...
# PROJECT_END_DATE_YEAR      0.079104 -0.074908  0.009134 -0.011188  ...
# ALLOCATION_START_DAY      -0.064045  0.003230  0.029049  0.042500  ...
# ALLOCATION_START_MONTH    -0.004378 -0.004657 -0.014250 -0.006390  ...
# ALLOCATION_START_YEAR      0.038239  0.016550 -0.035888 -0.013401  ...
# ALLOCATION_END_DAY         0.130810 -0.090003 -0.013922 -0.011037  ...
# ALLOCATION_END_MONTH      -0.047217  0.026760  0.011907 -0.000615  ...
# ALLOCATION_END_YEAR        0.049012  0.000787 -0.048676 -0.014410  ...
# WEEK_START_DAY             0.070760 -0.050850 -0.120165 -0.088053  ...
# WEEK_START_MONTH          -0.016221  0.050100 -0.004185  0.140296  ...
# WEEK_START_YEAR           -0.074619  0.111197 -0.035320 -0.061766  ...
# WEEK_END_DAY               0.069399 -0.033337 -0.085377 -0.051550  ...
# WEEK_END_MONTH            -0.039001  0.039494 -0.052700  0.093552  ...
# WEEK_END_YEAR              0.110638 -0.057225 -0.084500 -0.150163  ...
# project_category           0.066475 -0.031875  0.038098 -0.020931  ...
#
#                            ALLOCATION_END_DAY  ALLOCATION_END_MONTH  \
# ROLE                                -0.222022             -0.136868
# PROJECT_NAME                         0.064860             -0.002858
# PROJECT_DURATION                    -0.223823             -0.059842
# PROJECT_CATEGORY                     0.289585              0.028571
# ALLOCATION_DURATION                 -0.154869             -0.134808
# ACTIVITY                            -0.039619             -0.024237
# MON                                  0.130810             -0.047217
# TUE                                 -0.090003              0.026760
# WED                                 -0.013922              0.011907
# THUR                                -0.011037             -0.000615
# FRI                                  0.127107             -0.005196
# SAT                                  0.098179              0.033839
# SUN                                 -0.056883              0.118781
# TOTAL_WEEK_HOURS                     0.082398              0.045943
# HOURS_OVER_OR_UNDER                  0.082398              0.045943
# ATTENDANCE_REGULARIZATION            0.020695              0.011814
# FEEDBACK_SCORE                      -0.021591              0.153059
# PROJECT_START_DATE_DAY               0.010816              0.023763
# PROJECT_START_DATE_MONTH             0.052526             -0.004892
# PROJECT_START_DATE_YEAR              0.138918              0.114102
# PROJECT_END_DATE_DAY                 0.056112              0.069727
# PROJECT_END_DATE_MONTH              -0.046932             -0.081168
# PROJECT_END_DATE_YEAR                0.187464             -0.021970
# ALLOCATION_START_DAY                -0.038664             -0.074549
# ALLOCATION_START_MONTH               0.050377              0.808733
# ALLOCATION_START_YEAR                0.012338             -0.702715
# ALLOCATION_END_DAY                   1.000000             -0.047719
# ALLOCATION_END_MONTH                -0.047719              1.000000
# ALLOCATION_END_YEAR                  0.017831             -0.795523
# WEEK_START_DAY                       0.013639              0.072181
# WEEK_START_MONTH                     0.041092             -0.059078
# WEEK_START_YEAR                      0.091406              0.053446
# WEEK_END_DAY                        -0.013360              0.072677
# WEEK_END_MONTH                       0.099344             -0.065576
# WEEK_END_YEAR                       -0.112242              0.033181
# project_category                     0.289585              0.028571
#
#                            ALLOCATION_END_YEAR  WEEK_START_DAY  \
# ROLE                                  0.287346       -0.089772
# PROJECT_NAME                          0.016884       -0.025002
# PROJECT_DURATION                      0.013697       -0.025772
# PROJECT_CATEGORY                      0.015638       -0.017704
# ALLOCATION_DURATION                   0.202407        0.113473
# ACTIVITY                              0.017350        0.030031
# MON                                   0.049012        0.070760
# TUE                                   0.000787       -0.050850
# WED                                  -0.048676       -0.120165
# THUR                                 -0.014410       -0.088053
# FRI                                   0.063361        0.054397
# SAT                                   0.002457        0.200627
# SUN                                  -0.070510       -0.011525
# TOTAL_WEEK_HOURS                     -0.004145        0.003657
# HOURS_OVER_OR_UNDER                  -0.004145        0.003657
# ATTENDANCE_REGULARIZATION             0.014474       -0.019053
# FEEDBACK_SCORE                       -0.116991       -0.129116
# PROJECT_START_DATE_DAY               -0.019961        0.006359
# PROJECT_START_DATE_MONTH              0.000234        0.016279
# PROJECT_START_DATE_YEAR              -0.038076        0.037795
# PROJECT_END_DATE_DAY                 -0.050705        0.010102
# PROJECT_END_DATE_MONTH                0.051077        0.005410
# PROJECT_END_DATE_YEAR                 0.038822        0.056163
# ALLOCATION_START_DAY                 -0.025712       -0.170283
# ALLOCATION_START_MONTH               -0.629495        0.088091
# ALLOCATION_START_YEAR                 0.923263       -0.075235
# ALLOCATION_END_DAY                    0.017831        0.013639
# ALLOCATION_END_MONTH                 -0.795523        0.072181
# ALLOCATION_END_YEAR                   1.000000       -0.065438
# WEEK_START_DAY                       -0.065438        1.000000
# WEEK_START_MONTH                      0.062413       -0.820212
# WEEK_START_YEAR                      -0.032406        0.057853
# WEEK_END_DAY                         -0.077890        0.949267
# WEEK_END_MONTH                        0.088655       -0.770443
# WEEK_END_YEAR                        -0.048604       -0.156206
# project_category                      0.015638       -0.017704
#
#                            WEEK_START_MONTH  WEEK_START_YEAR  WEEK_END_DAY  \
# ROLE                               0.073192        -0.054631     -0.072655
# PROJECT_NAME                       0.038543        -0.020525     -0.041122
# PROJECT_DURATION                  -0.004831        -0.017720     -0.020175
# PROJECT_CATEGORY                   0.068611         0.051665     -0.027019
# ALLOCATION_DURATION               -0.069297        -0.114927      0.107676
# ACTIVITY                          -0.137921        -0.120711     -0.017571
# MON                               -0.016221        -0.074619      0.069399
# TUE                                0.050100         0.111197     -0.033337
# WED                               -0.004185        -0.035320     -0.085377
# THUR                               0.140296        -0.061766     -0.051550
# FRI                               -0.011171         0.031707      0.058517
# SAT                               -0.097831         0.024458      0.177587
# SUN                                0.011144        -0.056409     -0.009016
# TOTAL_WEEK_HOURS                   0.047769        -0.015111      0.029235
# HOURS_OVER_OR_UNDER                0.047769        -0.015111      0.029235
# ATTENDANCE_REGULARIZATION          0.048942        -0.096945      0.002488
# FEEDBACK_SCORE                     0.083831         0.040634     -0.112743
# PROJECT_START_DATE_DAY             0.034636        -0.035175      0.004658
# PROJECT_START_DATE_MONTH          -0.037497         0.005267      0.011097
# PROJECT_START_DATE_YEAR            0.024488        -0.079016      0.003221
# PROJECT_END_DATE_DAY               0.018503        -0.026096      0.002314
# PROJECT_END_DATE_MONTH            -0.012885        -0.010963      0.008697
# PROJECT_END_DATE_YEAR              0.002270        -0.043070      0.047520
# ALLOCATION_START_DAY               0.097325         0.094538     -0.152944
# ALLOCATION_START_MONTH            -0.039404         0.023426      0.080264
# ALLOCATION_START_YEAR              0.052847        -0.010824     -0.084379
# ALLOCATION_END_DAY                 0.041092         0.091406     -0.013360
# ALLOCATION_END_MONTH              -0.059078         0.053446      0.072677
# ALLOCATION_END_YEAR                0.062413        -0.032406     -0.077890
# WEEK_START_DAY                    -0.820212         0.057853      0.949267
# WEEK_START_MONTH                   1.000000        -0.114816     -0.729688
# WEEK_START_YEAR                   -0.114816         1.000000      0.116725
# WEEK_END_DAY                      -0.729688         0.116725      1.000000
# WEEK_END_MONTH                     0.873216        -0.100541     -0.833478
# WEEK_END_YEAR                      0.151870        -0.287278     -0.215969
# project_category                   0.068611         0.051665     -0.027019
#
#                            WEEK_END_MONTH  WEEK_END_YEAR  project_category
# ROLE                             0.037653       0.078203         -0.019503
# PROJECT_NAME                     0.065240       0.002844          0.053309
# PROJECT_DURATION                -0.015632       0.022930         -0.692614
# PROJECT_CATEGORY                 0.093880      -0.058345          1.000000
# ALLOCATION_DURATION             -0.083715       0.090326         -0.129180
# ACTIVITY                        -0.069390      -0.002848         -0.017304
# MON                             -0.039001       0.110638          0.066475
# TUE                              0.039494      -0.057225         -0.031875
# WED                             -0.052700      -0.084500          0.038098
# THUR                             0.093552      -0.150163         -0.020931
# FRI                             -0.027525       0.078297          0.023800
# SAT                             -0.062822      -0.059964          0.086765
# SUN                             -0.012892       0.148062          0.008513
# TOTAL_WEEK_HOURS                -0.000741       0.006586          0.072000
# HOURS_OVER_OR_UNDER             -0.000741       0.006586          0.072000
# ATTENDANCE_REGULARIZATION        0.005705      -0.015021          0.022617
# FEEDBACK_SCORE                   0.066740       0.017020         -0.008112
# PROJECT_START_DATE_DAY           0.032559       0.008582         -0.075961
# PROJECT_START_DATE_MONTH        -0.029919      -0.002928          0.082260
# PROJECT_START_DATE_YEAR          0.065333       0.034245          0.149026
# PROJECT_END_DATE_DAY             0.027359       0.008410         -0.056136
# PROJECT_END_DATE_MONTH          -0.021710       0.008380         -0.006047
# PROJECT_END_DATE_YEAR            0.012466      -0.046927          0.086934
# ALLOCATION_START_DAY             0.097456      -0.054037         -0.035193
# ALLOCATION_START_MONTH          -0.037474       0.048963          0.118247
# ALLOCATION_START_YEAR            0.077651      -0.069033         -0.024586
# ALLOCATION_END_DAY               0.099344      -0.112242          0.289585
# ALLOCATION_END_MONTH            -0.065576       0.033181          0.028571
# ALLOCATION_END_YEAR              0.088655      -0.048604          0.015638
# WEEK_START_DAY                  -0.770443      -0.156206         -0.017704
# WEEK_START_MONTH                 0.873216       0.151870          0.068611
# WEEK_START_YEAR                 -0.100541      -0.287278          0.051665
# WEEK_END_DAY                    -0.833478      -0.215969         -0.027019
# WEEK_END_MONTH                   1.000000       0.141978          0.093880
# WEEK_END_YEAR                    0.141978       1.000000         -0.058345
# project_category                 0.093880      -0.058345          1.000000
#
# [36 rows x 36 columns]

# %%
# import pandas as pd
# from scipy.stats import spearmanr

# # Assuming df contains your DataFrame

# # Compute Spearman correlation coefficients for numerical variables
# spearman_corr_numerical = df.corr(method='spearman')

# # Set the threshold for correlation coefficient
# threshold = 0.001  # Adjust as needed

# # Create a mask to identify features with correlation coefficients below the threshold
# mask = (spearman_corr_numerical.abs() < threshold).all()

# # Get the names of features to drop
# features_to_drop = spearman_corr_numerical.columns[mask]

# # Drop the irrelevant features from the DataFrame
# df.drop(columns=features_to_drop, inplace=True)

# # Show the updated DataFrame
# print(df)

# %%
# Save the DataFrame to a CSV file
df.to_csv('processed_data.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the distribution of attendance_regularization
plt.figure(figsize=(8, 6))
sns.countplot(x='ATTENDANCE_REGULARIZATION', data=df)
plt.title('Distribution of Attendance Regularization')
plt.xlabel('Attendance Regularization')
plt.ylabel('Count')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1899 entries, 0 to 4999
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ROLE                       1899 non-null   int64
#  1   PROJECT_NAME               1899 non-null   int32
#  2   PROJECT_DURATION           1899 non-null   int64
#  3   PROJECT_CATEGORY           1899 non-null   int8
#  4   ALLOCATION_DURATION        1899 non-null   int64
#  5   ACTIVITY                   1899 non-null   int8
#  6   MON                        1899 non-null   float64
#  7   TUE                        1899 non-null   float64
#  8   WED                        1899 non-null   float64
#  9   THUR                       1899 non-null   float64
#  10  FRI                        1899 non-null   float64
#  11  SAT                        1899 non-null   float64
#  12  SUN                        1899 non-null   float64
#  13  TOTAL_WEEK_HOURS           1899 non-null   float64
#  14  HOURS_OVER_OR_UNDER        1899 non-null   float64
#  15  ATTENDANCE_REGULARIZATION  1899 non-null   int64
#  16  FEEDBACK_SCORE             1899 non-null   float64
#  17  PROJECT_START_DATE_DAY     1899 non-null   category
#  18  PROJECT_START_DATE_MONTH   1899 non-null   category
#  19  PROJECT_START_DATE_YEAR    1899 non-null   category
#  20  PROJECT_END_DATE_DAY       1899 non-null   category
#  21  PROJECT_END_DATE_MONTH     1899 non-null   category
#  22  PROJECT_END_DATE_YEAR      1899 non-null   category
#  23  ALLOCATION_START_DAY       1899 non-null   category
#  24  ALLOCATION_START_MONTH     1899 non-null   category
#  25  ALLOCATION_START_YEAR      1899 non-null   category
#  26  ALLOCATION_END_DAY         1899 non-null   category
#  27  ALLOCATION_END_MONTH       1899 non-null   category
#  28  ALLOCATION_END_YEAR        1899 non-null   category
#  29  WEEK_START_DAY             1899 non-null   category
#  30  WEEK_START_MONTH           1899 non-null   category
#  31  WEEK_START_YEAR            1899 non-null   category
#  32  WEEK_END_DAY               1899 non-null   category
#  33  WEEK_END_MONTH             1899 non-null   category
#  34  WEEK_END_YEAR              1899 non-null   category
#  35  project_category           1899 non-null   int32
# dtypes: category(18), float64(10), int32(2), int64(4), int8(2)
# memory usage: 285.2 KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df contains your DataFrame with the ATTENDANCE_REGULARIZATION column

# Separate the True and False samples
df_true = df[df['ATTENDANCE_REGULARIZATION'] == True]
df_false = df[df['ATTENDANCE_REGULARIZATION'] == False]

# Downsample the False samples with replacement to match the number of True samples
df_false_downsampled = df_false.sample(n=len(df_true), replace=True, random_state=42)

# Concatenate the downsampled False samples with the True samples
df_balanced = pd.concat([df_true, df_false_downsampled])

# Shuffle the DataFrame
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Plot the distribution of attendance_regularization after balancing
plt.figure(figsize=(8, 6))
sns.countplot(x='ATTENDANCE_REGULARIZATION', data=df_balanced)
plt.title('Distribution of Attendance Regularization (Balanced)')
plt.xlabel('Attendance Regularization')
plt.ylabel('Count')
plt.show()

# %%
# from sklearn.metrics import classification_report

# # Assuming y_true contains the true labels and y_pred contains the predicted labels
# # Adjust the threshold for classification
# threshold = 0.4  # Adjust as needed

# # Convert predicted probabilities to binary predictions based on the adjusted threshold
# y_pred_adjusted = (y_pred_prob[:, 1] > threshold).astype(int)

# # Print the classification report
# print("Classification Report:")
# print(classification_report(y_true, y_pred_adjusted))

# %%
df.columns
# Out:
# Index(['ROLE', 'PROJECT_NAME', 'PROJECT_DURATION', 'PROJECT_CATEGORY',
#        'ALLOCATION_DURATION', 'ACTIVITY', 'MON', 'TUE', 'WED', 'THUR', 'FRI',
#        'SAT', 'SUN', 'TOTAL_WEEK_HOURS', 'HOURS_OVER_OR_UNDER',
#        'ATTENDANCE_REGULARIZATION', 'FEEDBACK_SCORE', 'PROJECT_START_DATE_DAY',
#        'PROJECT_START_DATE_MONTH', 'PROJECT_START_DATE_YEAR',
#        'PROJECT_END_DATE_DAY', 'PROJECT_END_DATE_MONTH',
#        'PROJECT_END_DATE_YEAR', 'ALLOCATION_START_DAY',
#        'ALLOCATION_START_MONTH', 'ALLOCATION_START_YEAR', 'ALLOCATION_END_DAY',
#        'ALLOCATION_END_MONTH', 'ALLOCATION_END_YEAR', 'WEEK_START_DAY',
#        'WEEK_START_MONTH', 'WEEK_START_YEAR', 'WEEK_END_DAY', 'WEEK_END_MONTH',
#        'WEEK_END_YEAR', 'project_category'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# Assuming df is your DataFrame
# Replace df with your actual DataFrame

# Prepare features (X) and target variable (y)
X = df.iloc[:, :-1]  # All columns except the last one
y = df.iloc[:, -1]   # Last column

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Dictionary to hold models
models = {
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(),
}

# Train and evaluate each model
for name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    
    # Predict on the testing set
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{name} Accuracy:", accuracy)
    
    # Generate classification report
    report = classification_report(y_test, y_pred)
    print(f"{name} Classification Report:")
    print(report)
# Out:
# K-Nearest Neighbors Accuracy: 0.975
# K-Nearest Neighbors Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       623
#            1       0.93      0.93      0.93       137
#
#     accuracy                           0.97       760
#    macro avg       0.96      0.96      0.96       760
# weighted avg       0.98      0.97      0.98       760
#
# Support Vector Machine Accuracy: 0.8197368421052632
# Support Vector Machine Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90       623
#            1       0.00      0.00      0.00       137
#
#     accuracy                           0.82       760
#    macro avg       0.41      0.50      0.45       760
# weighted avg       0.67      0.82      0.74       760
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AadishNagarajan\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.under_sampling import RandomUnderSampler

# Separate the features (X) and the target variable (y)
X = df.drop(columns=['ATTENDANCE_REGULARIZATION'])
y = df['ATTENDANCE_REGULARIZATION']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Undersample the majority class to balance the dataset
undersampler = RandomUnderSampler(random_state=42)
X_balanced, y_balanced = undersampler.fit_resample(X_train, y_train)

# Initialize SVM classifier with adjusted hyperparameters
svm_classifier = SVC(kernel='rbf', C=0.1, gamma='scale')

# Train SVM classifier
svm_classifier.fit(X_balanced, y_balanced)

# Make predictions on test data
svm_predictions = svm_classifier.predict(X_test)

# Evaluate SVM model
svm_accuracy = accuracy_score(y_test, svm_predictions)
svm_classification_report = classification_report(y_test, svm_predictions)
print("SVM Accuracy:", svm_accuracy)
print("SVM Classification Report:\n", svm_classification_report)

# Initialize KNN classifier with adjusted hyperparameters
knn_classifier = KNeighborsClassifier(n_neighbors=3, weights='distance')

# Train KNN classifier
knn_classifier.fit(X_balanced, y_balanced)

# Make predictions on test data
knn_predictions = knn_classifier.predict(X_test)

# Evaluate KNN model
knn_accuracy = accuracy_score(y_test, knn_predictions)
knn_classification_report = classification_report(y_test, knn_predictions)
print("\nKNN Accuracy:", knn_accuracy)
print("KNN Classification Report:\n", knn_classification_report)

# Plot the distribution of attendance regularization after balancing
plt.figure(figsize=(8, 6))
sns.countplot(x=y_balanced, data=df_balanced)
plt.title('Distribution of Attendance Regularization (Balanced)')
plt.xlabel('Attendance Regularization')
plt.ylabel('Count')
plt.show()
# Out:
# SVM Accuracy: 0.8513157894736842
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       176
#            1       1.00      0.81      0.89       584
#
#     accuracy                           0.85       760
#    macro avg       0.80      0.90      0.82       760
# weighted avg       0.91      0.85      0.86       760
#
#
# KNN Accuracy: 0.9210526315789473
# KNN Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.97      0.85       176
#            1       0.99      0.91      0.95       584
#
#     accuracy                           0.92       760
#    macro avg       0.87      0.94      0.90       760
# weighted avg       0.94      0.92      0.92       760

# %%
# Assuming 'new_data' contains the data for prediction (excluding the target variable)
new_data = pd.read_csv("new_data.csv")

# Make predictions on the new data
predictions = rf_classifier.predict(new_data)

# Add the predictions to the DataFrame
new_data['attendance_regularization_prediction'] = predictions

# Display the DataFrame with predictions
print(new_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[521], line 5
#       2 new_data = pd.read_csv("new_data.csv")
#       4 # Make predictions on the new data
# ----> 5 predictions = rf_classifier.predict(new_data)
#       7 # Add the predictions to the DataFrame
#       8 new_data['attendance_regularization_prediction'] = predictions
#
# NameError: name 'rf_classifier' is not defined

# %%
X_train
